# %% [markdown]
# ### __BUSA8001 (S2, 2023) Group Assignment - Predicting Used Car Sale Prices__

# %% [markdown]
# ---
#
# **Kaggle Competition Ends:** Friday, 3 November 2023 @ 3:00pm (Week 13)
# **Assignment Due Date on iLearn:** Friday, 3 November 2023 @ 11.59pm (Week 13)
#
# **Overview:**
#
# - In the group assignment you will form a team of 3 students and participate in a forecasting competition on Kaggle
# - The goal is to predict prices of used cars based on car characteristics and regression models
# - Assessment Summary:
#     - Write a problem statement and perform Exploratory Data Analysis
#     - Clean up data, deal with categorical features and missing observations, and create new explanatory variables (feature engineering)
#     - Construct and tune forecasting models, produce forecasts and submit your predictions to Kaggle
#     - Each member of the team will record a video presentation of their work

# %% [markdown]
# **Instructions:**
#
# - Form a team of 3 students
# - Each team member needs to join [https://www.kaggle.com](https://www.kaggle.com/)
# - Choose a team leader and form a team in the competition [https://www.kaggle.com/t/32b34f072642495487836cf93453ac6a](https://www.kaggle.com/t/32b34f072642495487836cf93453ac6a)
#     - Team leader to click on `team` and join and invite other 2 team members to join
#     - Your **team's name must start** with our unit code, for instance you could have a team called BUSA8001_masterful_geniuses
# - All team members should work on all the tasks however
#     - Choose a team member who will be responsible for one of each of the 3 tasks listed below
# - Your predictions must be generated by a model you develop here
#     - You will receive a mark of **zero** if your code does not produce the forecasts you submit to Kaggle

# %% [markdown]
# **Marks**:
#
# - Total Marks: 40
# - Your individual mark will consist of:
#     - 50% x overall assignment mark + 45% x mark for the task that you are responsible for + 5% x mark received from your teammates for your effort in group work
# - 1 mark: Ranking in the top 5 places of your unit on Kaggle
# - 3 marks: Reaching the first place in the competition

# %% [markdown]
# **Submissions:**
#
# 1. On Kaggle: submit your team's forecast in order to be ranked by Kaggle
#     - Limit of 20 submission per day
# 2. On iLearn **only team leader to submit** this Jupyter notebook re-named `Group_Assignment_Team_Name.ipynb` where Team_Name is your team's name on Kaggle
#     - The Jupyter notebook must contain team members names/ID numbers, and team name in the competition
#     - Provide answers to the 3 Tasks below in the allocated cells including all codes/outputs/writeups
#     - One 15 minute video recording of your work
#         - Each team member to provide a 5 minute presentation of the Task that they led (it is best to jointly record your video using Zoom)
#         - When recording your video make sure your face is visible, that you share your Jupyter Notebook and explain everything you've done in the submitted Jupyter notebook on screen
#         - 5 marks will be deducted from each Task for which there is no video presentation or if you don't follow the above instructions
#
# 3. On iLearn each student needs to submit a file with their teammates' names, ID number and a mark for their group effort (out of 100%)

# %% [markdown]
# ---

# %% [markdown]
# **Fill out the following information**
#
# For each team member provide name, Student ID number and which task is performed below

# %% [markdown]
# - Team Name on Kaggle: BUSA8001_mschiefs
# - Team Leader and Team Member 1: Ha Thanh (Taylor) Chu, 47484039, Task 3
# - Team Member 2: `(insert here)`
# - Team Member 3: `(insert here)`

# %% [markdown]
# ---
#
# ## Task 1: Problem Description and Initial Data Analysis
#
# 1. Read the Competition Overview on Kaggle [https://www.kaggle.com/t/32b34f072642495487836cf93453ac6a](https://www.kaggle.com/t/32b34f072642495487836cf93453ac6a)
# 2. Referring to Competition Overview and the data provided on Kaggle write **Problem Description** (about 500 words) focusing on key points that will need to be addressed as first steps in Tasks 2 and 3 below,
#
# - Using the following headings:
#     - Forecasting Problem - explain what you are trying to do and how it could be used in the real world (i.e. why it may be important)
#     - Evaluation Criteria - explain the criteria is used to assess forecast performance
#     - Types of Variables/Features
#     - Data summary and main data characteristics
#     - Missing Values (only explain what you find - do not impute missing values at this stage)
#     - You should **not** discuss any specific predictive algorithms at this stage
#     - Note: Your written portion of this task should be completed in a single Markdown cell
#
# Total Marks: 12

# %%
#Task 1 code here, insert more cells if required

# %% [markdown]
# `(Task 1, Text Here - insert more cells as required)`

# %% [markdown]
# ---
#
# ## Task 2: Data Cleaning, Missing Observations and Feature Engineering
# - In this task you will follow a set of instructions/questions listed below.
# - Make sure you explain each answer carefully both in Markdown text and on your video.
#
# Total Marks: 12

# %% [markdown]
# **Task 2, Question 1**: Clean **all** numerical features so that they can be used in training algorithms. For instance, back_legroom feature is in object format containing both numerical values and text. Extract numerical values (equivalently eliminate the text) so that the numerical values can be used as a regular feature.
# (2 marks)

# %%
## Task 2, Question 1 Code Here

import pandas as pd

car = pd.read_csv('train.csv')

car.head()
# Out:
#                  vin back_legroom        body_type          city  \
# 0  SJKCH5CRXHA032566      33.5 in  SUV / Crossover    Great Neck
# 1  5LMCJ3D96HUL54638      36.8 in  SUV / Crossover         Wayne
# 2  5LMCJ2D95HUL35217      36.8 in  SUV / Crossover         Wayne
# 3  2HGFG1B86AH500600      30.3 in            Coupe  Little Ferry
# 4  5LMCJ1D95LUL25032      38.6 in  SUV / Crossover         Wayne
#
#    city_fuel_economy  daysonmarket  dealer_zip  engine_displacement  \
# 0                NaN            20       11021               2000.0
# 1               19.0            64        7470               2300.0
# 2               19.0            14        7470               2300.0
# 3               25.0            13        7643               1800.0
# 4               21.0            14        7470               2000.0
#
#   engine_type                             exterior_color  ...  savings_amount  \
# 0          I4                                      Black  ...            1522
# 1          I4                     Magnetic Gray Metallic  ...             740
# 2          I4  Burgundy Velvet Metallic Tinted Clearcoat  ...             832
# 3          I4                                       Blue  ...             983
# 4          I4                                        Red  ...               0
#
#   seller_rating                 torque transmission transmission_display  \
# 0      3.346154  258 lb-ft @ 1,200 RPM            A    7-Speed Automatic
# 1      4.750000  300 lb-ft @ 2,000 RPM            A    6-Speed Automatic
# 2      4.750000  300 lb-ft @ 2,000 RPM            A    6-Speed Automatic
# 3      3.577778  128 lb-ft @ 4,300 RPM            A    5-Speed Automatic
# 4      4.750000  275 lb-ft @ 3,000 RPM            A    8-Speed Automatic
#
#    wheel_system  wheelbase    width  year  price
# 0           AWD   106.3 in    82 in  2017  21495
# 1           AWD   105.9 in  84.1 in  2017  22459
# 2           AWD   105.9 in  84.1 in  2017  24799
# 3           FWD   104.3 in  68.9 in  2010   3750
# 4           AWD   106.7 in    83 in  2020  40669
#
# [5 rows x 39 columns]

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3500 entries, 0 to 3499
# Data columns (total 39 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   vin                   3500 non-null   object
#  1   back_legroom          3397 non-null   object
#  2   body_type             3494 non-null   object
#  3   city                  3500 non-null   object
#  4   city_fuel_economy     2912 non-null   float64
#  5   daysonmarket          3500 non-null   int64
#  6   dealer_zip            3500 non-null   int64
#  7   engine_displacement   3375 non-null   float64
#  8   engine_type           3450 non-null   object
#  9   exterior_color        3500 non-null   object
#  10  franchise_dealer      3500 non-null   bool
#  11  front_legroom         3397 non-null   object
#  12  fuel_tank_volume      3397 non-null   object
#  13  fuel_type             3463 non-null   object
#  14  height                3397 non-null   object
#  15  highway_fuel_economy  2912 non-null   float64
#  16  horsepower            3375 non-null   float64
#  17  interior_color        3500 non-null   object
#  18  is_new                3500 non-null   bool
#  19  latitude              3500 non-null   float64
#  20  length                3397 non-null   object
#  21  listed_date           3500 non-null   object
#  22  listing_color         3500 non-null   object
#  23  longitude             3500 non-null   float64
#  24  make_name             3500 non-null   object
#  25  maximum_seating       3397 non-null   object
#  26  mileage               3297 non-null   float64
#  27  model_name            3500 non-null   object
#  28  power                 3201 non-null   object
#  29  savings_amount        3500 non-null   int64
#  30  seller_rating         3500 non-null   float64
#  31  torque                3169 non-null   object
#  32  transmission          3440 non-null   object
#  33  transmission_display  3440 non-null   object
#  34  wheel_system          3399 non-null   object
#  35  wheelbase             3397 non-null   object
#  36  width                 3397 non-null   object
#  37  year                  3500 non-null   int64
#  38  price                 3500 non-null   int64
# dtypes: bool(2), float64(8), int64(5), object(24)
# memory usage: 1018.7+ KB

# %%
car.isna().sum()
# Out:
# vin                       0
# back_legroom            103
# body_type                 6
# city                      0
# city_fuel_economy       588
# daysonmarket              0
# dealer_zip                0
# engine_displacement     125
# engine_type              50
# exterior_color            0
# franchise_dealer          0
# front_legroom           103
# fuel_tank_volume        103
# fuel_type                37
# height                  103
# highway_fuel_economy    588
# horsepower              125
# interior_color            0
# is_new                    0
# latitude                  0
# length                  103
# listed_date               0
# listing_color             0
# longitude                 0
# make_name                 0
# maximum_seating         103
# mileage                 203
# model_name                0
# power                   299
# savings_amount            0
# seller_rating             0
# torque                  331
# transmission             60
# transmission_display     60
# wheel_system            101
# wheelbase               103
# width                   103
# year                      0
# price                     0
# dtype: int64

# %%
for col in car:
  print(col + str(car[col].unique()))
# Out:
# vin['SJKCH5CRXHA032566' '5LMCJ3D96HUL54638' '5LMCJ2D95HUL35217' ...
#  '1FMCU9J90KUB72183' '2C3CDXGJ0LH121690' '5NPEF4JA9LH051412']
# back_legroom['33.5 in' '36.8 in' '30.3 in' '38.6 in' '39.9 in' '44.4 in' '45.2 in'
#  '38.5 in' '38.3 in' '39.1 in' '40.3 in' '37.2 in' '34.6 in' '39.6 in' nan
#  '30.6 in' '39.7 in' '35 in' '41 in' '37.4 in' '34.8 in' '39.4 in'
#  '38.2 in' '36.6 in' '38.7 in' '35.6 in' '42 in' '36.1 in' '35.9 in'
#  '33.1 in' '37.9 in' '34.2 in' '35.7 in' '40 in' '36 in' '34 in' '35.2 in'
#  '29 in' '43 in' '35.3 in' '35.1 in' '43.6 in' '36.5 in' '37.1 in' '--'
#  '38.1 in' '40.1 in' '39.5 in' '40.6 in' '42.8 in' '38 in' '37.8 in'
#  '42.1 in' '41.1 in' '32.4 in' '40.4 in' '41.7 in' '36.7 in' '42.6 in'
#  '35.8 in' '37 in' '38.4 in' '34.7 in' '40.9 in' '36.2 in' '39 in'
#  '38.8 in' '42.4 in' '37.7 in' '32.6 in' '40.2 in' '33 in' '39.8 in'
#  '35.5 in' '38.9 in' '34.3 in' '33.8 in' '35.4 in' '37.6 in' '27.1 in'
#  '36.4 in' '28.6 in' '39.3 in' '0 in' '44.3 in' '37.3 in' '33.4 in'
#  '33.7 in' '34.1 in' '29.8 in' '33.2 in' '36.3 in' '43.4 in' '31.9 in'
#  '27.3 in' '31.2 in' '27.2 in' '32.9 in' '41.4 in' '34.5 in' '29.9 in'
#  '40.7 in' '29.2 in' '41.3 in' '32.7 in' '31.8 in' '31.7 in' '33.9 in'
#  '33.3 in' '42.3 in' '43.3 in' '41.9 in' '36.9 in' '32 in' '39.2 in'
#  '34.4 in' '24.6 in' '20.2 in' '41.5 in' '43.5 in' '30.5 in' '28.9 in'
#  '32.1 in' '31.6 in' '32.2 in' '31.1 in' '41.6 in' '41.8 in' '31.3 in'
#  '33.6 in' '31.5 in' '28.2 in' '31.4 in' '34.9 in' '32.8 in' '42.9 in'
#  '30.8 in' '30.1 in' '47.5 in']
# body_type['SUV / Crossover' 'Coupe' 'Sedan' 'Pickup Truck' 'Wagon' 'Hatchback'
#  'Convertible' 'Minivan' 'Van' nan]
# city['Great Neck' 'Wayne' 'Little Ferry' 'Bay Shore' 'East Hartford' 'Bohemia'
#  'Patchogue' 'West Nyack' 'Green Brook' 'Bronx' 'Rockville Centre' 'Lodi'
#  'Detroit' 'Roselle' 'Stamford' 'East Meadow' 'Springfield' 'Meriden'
#  'Wallingford' 'West Hartford' 'Islip Terrace' 'Waterford' 'Huntington'
#  'Redford' 'North Plainfield' 'Linden' 'San Juan' 'Croton-On-Hudson'
#  'New Hudson' 'Howell' 'Holly' 'Teterboro' 'Greenwich' 'Copiague'
#  'Lakewood' 'Bayamon' 'Robbinsville' 'Woodbury' 'Michigan Center'
#  'Sterling Heights' 'Long Island City' 'Danbury' 'Staten Island']
# city_fuel_economy[ nan  19.  25.  21.  16.  15.  17.  34.  22.  20.  23.  27.  13.  18.
#   26.  28.  24.  37.  46. 127.  12.  14.  29.  51.  30.  31.  42.  43.
#   48.  35.  44.  33.  45.  53.  55.  47.  54.  36.  32.  41.  40.  10.
#   57.  66.  11.]
# daysonmarket[ 20  64  14  13 213 181 406 249  39  25 189  45   7  22  47  38  19  27
#    5  76   4 266  28  77  15  33  46  87  26   6  12  18 178   2  49   8
#   73 193  11  50 183  95  36  17  99  54 530   3  29 105  35   0 278 104
#   70  48 187 186  53  56 395  40  93  80 126  21  41  24  10 199 137 252
#  215 308 335 194  75  57 269 124 241  43  31 392  82  92  97  55 230 185
#  180 202  79 536 207  62  16 123 305 197  68   1  34 103  96  67 133  32
#  115  78  83  74 146 388 276 288 447 201 410 216  52 256 210 238  44 310
#  118 140  30 411 208 244  60 280 131 112 120  89 248 314 324 111  37 198
#  620   9 385  69  94 378 227 224  81 159 473 589  42 234 152 369 143  51
#   90 399 292 223  61 102 151 255 384 247 190 113  63 319 261  98 412 127
#  233 307 237 242  59 235 389 427 398 532 327 214 283 173 361 212 286 136
#  633 217  71 236 304 195 570 125 196 328 337 203 271 364 182 253 265 176
#   72 209 522 272 177 106  58 116 167 179 430 174 343 481 383 166 380 626
#  170 221 362 515  86  91 322 372 109  84 130 505 222 439 254 325 352 264
#  139 246 147 260 336 340 462 404 259 279 206 403 390 117 630 100 267 110
#  270 294 250 417  23 339  88 553 341 192 121 282 333 418 300 519 529 448
#  188 298 299 175 301 348 239 154 405 334 161 306 263 169 101 204 225 141
#  156 349 539 172 262 571 257 200 346 493 444 287 218 452 549 363 458 354
#  682 274 486 228 145 321 510 698 312 153 461 468 356 587 467 415 132 231
#  433 353 291  66 297 277 438 326 509]
# dealer_zip[11021  7470  7643 11706  6108 11716 11772 10994  8812 10466 11570  7644
#  48219  7203  6902 11554  1119  6450  6492 48207  6110 11752 48328 11743
#  48240  7060  7036   922  1109 10520 48165 48843 48442  7608  6830 11726
#   8701 11023   960  8691 11797 49203 48310 11101  6810 10304]
# engine_displacement[2000. 2300. 1800. 1500. 4400. 5700. 3000. 3500. 1600. 3200. 2500. 2400.
#    nan 5000. 5300. 5600. 1400. 3600. 1700. 1200. 5500. 6700. 4600. 3300.
#  4700. 2700. 4000. 3800. 6000. 6200. 4800. 3700. 6400. 1300. 2800. 1000.
#  5200. 4200. 2200. 4300. 2100. 5400. 3100. 6600. 3400. 7000. 5900.]
# engine_type['I4' 'V8' 'V6' 'I4 Hybrid' 'V8 Flex Fuel Vehicle' 'I3' 'V8 Biodiesel'
#  'H4' nan 'W12' 'V6 Flex Fuel Vehicle' 'I6' 'V8 Diesel' 'V10' 'V6 Hybrid'
#  'I6 Diesel' 'I5' 'I4 Flex Fuel Vehicle' 'I4 Diesel' 'V12' 'V6 Diesel']
# exterior_color['Black' 'Magnetic Gray Metallic'
#  'Burgundy Velvet Metallic Tinted Clearcoat' 'Blue' 'Red'
#  'Silver Ice Metallic' 'Bright White Clearcoat' 'Grey' 'Silver'
#  'Bright Silver' 'Diamond Black Crystal Pearlcoat' 'SIL'
#  'Black Plum Pearl' 'Magnetic Gray' 'BLACK' 'True Blue Pearlcoat' 'Yellow'
#  'Snowflake White Pearl Mica' 'Gray' 'Summit White'
#  'Pyrite Silver Metallic' 'Stormy Sea' 'FROST WHITE PEARL'
#  'Black Noir Pearl' 'Quicksilver Metallic' 'Soul Red Metallic'
#  'Cajun Red Tintcoat' 'Ebony Black' 'GRAY' 'ORANGE' 'Desert Sand'
#  'Harbor Gray Metallic' 'Caspian Blue' 'Oxford White' 'Super Black'
#  'Deep Crystal Blue Mica' 'White' 'STORMY SEA' 'WHITE'
#  'Pepperdust Metallic' 'Black Currant Metallic' 'GREY' 'BRIGHT_SILVER_M'
#  'Black Velvet' 'RED' 'Machine Gray Metallic' 'Charcoal'
#  'BLACK NOIR PEARL' 'Metal Stream' 'OSMIUM_GREY_M' 'Azul'
#  'Agate Black Metallic' 'Indus Silver' 'Firecracker Red Clearcoat'
#  'White Clearcoat' 'Eternal Blue Mica' 'Jetset Blue' 'Firenze Red'
#  'Pristine W' 'Namib Orange Premium' 'Clear White' 'BLUE'
#  'Radiant Silver Metallic' 'SILVER' 'PURE WHITE' 'Caspian Black'
#  'Ibis White' 'DAZZLING WHITE' 'Granite Crystal Metallic Clearcoat'
#  'Pure White' 'Gravity Blue' 'SURF BLUE' 'Santorini Black' 'Silky Silver'
#  'Brilliant Black Crystal Pearlcoat' 'Vice White' 'Liquid Platinum'
#  'Monaco White' 'Gold' 'Titanium Silver' 'Ice Silver Metallic'
#  'Alto Blue Metallic Tinted Clearcoat' 'Shadow Black' 'Wh'
#  'Hellayella Clearcoat' 'Majestic White' 'DB Black Crystal Clearcoat'
#  'Steel Gray Metallic' 'Midnight Sapphire Blue Metallic'
#  'Deep Ocean Blue Metallic' 'Sonic Silver Metallic'
#  'Billet Metallic Clearcoat' 'Crimson Red' 'Blue Streak Pearlcoat'
#  'AQUA BLUE' 'Monsoon Gray Metallic' 'ONYX_BLACK_META' 'Dusk Blue'
#  'SCARLET RED' 'white' 'Mosaic Black Metallic' 'Spectra Blue'
#  'Stellar Black Metallic' 'Taffeta White' 'GLOWING YELLOW'
#  'Billet Silver Metallic Clearcoat' 'Jet Black Mica'
#  'Pitch Black Clearcoat' 'COLISEUM GREY' 'Midnight Black'
#  'White Knuckle Clearcoat' 'Radiance' 'Platinum Gray Metallic'
#  'Gemstone Red' 'Alabaster Silver Metallic' 'CRYSTAL_WHITE_M' 'URBAN GRAY'
#  'Gravity Gray' 'Snow White Pearl' 'Super White' 'Red Horizon Tintcoat'
#  'Titanium Gray' 'Green' 'Sting Gray Clearcoat'
#  'Ruby Red Metallic Tinted Clearcoat' 'TWILIGHT BLACK'
#  'White Frost Tricoat' 'Sakhir Orange II Metallic' 'MAROON'
#  'DENIM BLUE MET' 'Black Sapphire Metallic' 'LIME TWIST' 'Black Raven'
#  'Billet Silver Metallic Clear Coat' 'STELLAR SILVER' 'Alpine White'
#  'Nightfall Gray Metallic' 'White Diamond' 'Florett Silver Metallic'
#  'Deep Blue Pearl' 'Granite Pearlcoat' 'None' 'Polished Metal Metallic'
#  'Db Black Clearcoat' 'Glacier Metallic' 'Graphite'
#  'Magnetic Force Metallic' 'Orca Black Metallic' 'Polar White'
#  'PORTOFINO GRAY' 'Black Clear Coat' 'Urban Titanium Metallic'
#  'Glacier White Metallic' 'Brilliant Silver' 'Carbon Black Metallic'
#  'DUSK BLUE' 'Iridium Silver Metallic' 'Granite Pearl Coat' 'Ultra Black'
#  'Cosmic Gray Mica' 'Winter White' 'Portofino Gray'
#  'Modern Steel Metallic' 'CALYPSO RED' 'Chalk White/Black Roof'
#  'Deep Black Pearl Effect' 'Blue Water Metallic' 'Pacific Blue'
#  'Blueprint' 'Brilliant Black' 'Eminent White Pearl' 'Ceramic White'
#  'Gris' 'Destroyer Gray Clearcoat' 'Hampton Gray' 'Crystal Black Silica'
#  'Black Cherry' 'Deep Cerulean' 'Slate Blue Pearlcoat'
#  'Osmium Gray Metallic' 'White Platinum' 'CASPIAN BLACK' 'Phantom Black'
#  'Tungsten Metallic' 'ELECTRIC BLUE METALLIC' 'Iridium Metallic'
#  'Canyon Ridge' 'BLK' 'GY' 'Laser Blue Pearlcoat' 'Bright White'
#  'Tangerine Orange Pearl' 'Torred Clearcoat' 'DENIM_BLUE_M' 'Fuji White'
#  'Molten Silver' 'Cordovan' 'Aurora Black' 'Moonlight Blue Metallic'
#  'GEMSTONE RED' 'Crystal White Pearl Mica' 'Lightning Blue'
#  'Ebony Twilight Metallic' 'LAGUNA BLUE' 'Frozen White' 'Burgundy'
#  'Sparkling Silver' 'Maximum Steel Metallic Clearcoat' 'CASABLANCA WHITE'
#  'PHANTOM BLACK' 'QUARTZ WHITE PEARL' 'Mythos Black Metallic'
#  'Black Granite Metallic' 'THUNDER GRAY' 'Imperial Blue Metallic'
#  'Ooh La La Rouge Mica' 'Silk Blue Metallic' 'Atomic Silver'
#  'CRYSTAL BLUE' 'ORANGR' 'Scarlet Red' 'ONYX_BLACK_MET'
#  'Light Silver Metallic/Black Roof' 'CHALK WHITE' 'Pacific Blue Metallic'
#  'Iconic Silver' 'Rhino Clearcoat' 'Ruby' 'White Diamond Pearl'
#  'Horizon Blue' 'Stealth Gray' 'Crystal White Metallic' 'BL'
#  'Ceramic Silver' 'Cashmere Pearlcoat' 'Daytona Gray Pearl Effect'
#  'Palladium White Gold Metallic' 'Soul Red Crystal Metallic'
#  'Pantera Metal' 'Racing Red' 'Quartz White Pearl' 'Lakeside Blue'
#  'WHITE CREAM' 'Cyber Gray Metallic' 'Crystal White Pearl' 'Cosmos Blue'
#  'granite crystal metallic clearcoat' 'Quartz White'
#  'Classic Silver Metallic' 'gold' 'Cashmere Silver Metallic'
#  'Predawn Gray Mica' 'Iridium Blue' 'Onyx Black' 'DENIM' 'GRIS'
#  'FLUID METAL' 'SHIMMERING SILVER PEARL' 'Undercover Green' 'Red Hot'
#  'Satin Steel Metallic' 'gray' 'Mars Orange/Black Roof' 'Surf Blue'
#  'Steel Gray' 'Molten Orange Metallic Tri-Coat' 'Bright Silver Metallic'
#  'Velvet Red Pearlcoat' 'Kaikoura Stone' 'Blue Streak Pearl' 'RUBY WINE'
#  'Bellanova White Pearl' 'SAVILLE_GRAY_M' 'Silver Metallic'
#  'Gotham Gray Metallic' 'Black Obsidian' 'Deep Sea Blue Metallic'
#  'Steel Sapphire Metallic' 'Moonstone Silver' 'Octane Red Pearlcoat'
#  'Supersonic Red' 'GREEN APPLE' 'Aurora Black Pearl' 'Cherry Black'
#  'Black Clearcoat' 'Carpathian Gray Premium' 'MAGNETIC FORCE' 'Ruby Wine'
#  'Crystal White Tricoat' 'Brown Sugar Metallic' 'Fresh Powder'
#  'Wave Metallic' 'INYX BLACK META' 'Callisto Gray Metallic'
#  'Magnetic Metallic' 'Race Red' 'Delmonico Red Pearlcoat'
#  'Tornado Gray Metallic' 'Steel' 'Narvik Black' 'Kinetic Blue Metallic'
#  'F8 Green Clearcoat' 'ONYX_BLACK' 'Granite' 'Pearl White Tricoat'
#  'Blue Jeans' 'QUARTZ WHITE' 'Iridescent Pearl Tricoat'
#  'Midnight Black Metallic' 'phantom gray metallic' 'Pearl White'
#  'MALLORCA BLUE' 'Neptune Blue' 'Mocha' 'Blue Ray Metallic' 'Dark Slate'
#  'Rapid Red Metallic Tinted Clearcoat' 'Deep Sea Blue' 'Dazzling White'
#  'Passion Red' 'Canyon Ridge Metallic' 'Space Gray Metallic'
#  'Seaside Pearl' 'Twilight Blue Metallic' 'Dark Cherry'
#  'Moondust Silver Metallic' 'Hyper Red' 'Black Cherry Pearl'
#  'Atlantis Blue Metallic' 'Cinnamon Glaze Metallic' 'Ash Black'
#  'Gun Metallic' 'Black Velvet Metallic' 'Agate Black' 'HAMPTON GRAY'
#  'Graphite Gray Metallic' 'Coliseum Gray' 'designo Diamond White Metallic'
#  'Diamond White' 'Brilliant Black Crystal Pearl'
#  'Hockenheim Silver Metallic' 'Moonlight White' 'MACHINE GRAY'
#  'Dakota Brown Metallic' 'Magnetic Black' 'Jet Black' 'black'
#  'Crystal Black Pearl' 'Estoril Blue Metallic' 'Graphite Metallic'
#  'Mars Orange' 'SONIC SILVER' 'SPACE BLUE PEARL' 'Gunmetal Metallic'
#  'Black Diamond Tricoat' 'Himalayan Gray' 'Diamond Silver Metallic'
#  'Yulong White' 'Taupe Gray Metallic' 'Mineral White Metallic'
#  'Shadow Metallic' 'Midnight Blue Metallic' 'Ashen Gray Metallic'
#  'billet silver metallic clearcoat' 'Galactic Aqua Mica' 'CENTURY WHITE'
#  'CRYSTL_WHITE_ME' 'Byron Blue' 'Portofino Blue' 'Opulent Amber'
#  'Sunshine Orange' 'DENIM_BLUE_META' 'Everlasting Silver' 'Glacier White'
#  'Nero' 'Siren Red Tintcoat' 'Jupiter Red' 'Silver Grey Metallic'
#  'Geranium Red' 'Deep Cherry Red Crystal Pearlcoat'
#  'Black Cherry Metallic' 'Cream White Pearl' 'Shadow Gray Metallic'
#  'CRYSTAL WHITE M' 'ULTRA BLACK' 'Pebble Gray Metallic'
#  'Argus Brown Metallic' 'Black Metallic' 'Tuxedo Black Metallic'
#  'Black Copper' 'Pure Red' 'Champagne' 'CD Silver Metallic'
#  'Ultra Silver Metallic' 'Currant Red' 'Obsidian Blue Pearl'
#  'SYMPHONY SILVER' 'Scarlet Red Pearl' 'White Silver Metallic' 'Magnetic'
#  'Sterling Gray Metallic' 'Anvil Clear Coat' 'Deep Black Metallic'
#  'Dark Gray Metallic' 'Glacier Silver Metallic' 'Matte Gray' 'Silver Sky'
#  'Ingot Silver' 'Cosmic Blue Metallic' 'Reactor Blue Pearlcoat'
#  'walnut brown metallic clearcoat' 'Ruby Red' 'GREEN' 'Deep Crystal Blue'
#  'OSMIUM GREY MET' 'Pitch Black Clear Coat' 'Garnet Metallic'
#  'White Platinum Metallic Tri-Coat' 'Metallic Green Pearl-Mica'
#  'Dark Green Metallic' 'Deep Chroma Blue' 'Turquoise'
#  'Zermatt Silver Metallic' 'Eiger Gray' 'Silver Birch Metallic'
#  'LAKESIDE BLUE' 'Brown' 'CARIBBEAN BLUE' 'Inferno Red Crystal Pearl'
#  'Beige' 'DENIM_BLUE_MET' 'Indigo Blue Pearl' 'Azurite Black Metallic'
#  'Granite Crystal Metallic Clear Coat' 'White Clear Coat' 'Stellar Silver'
#  'Brilliant Black Crystal Pearl Coat' 'Inferno Red' 'Gobi Clearcoat'
#  'Puro White Tri-Coat Pearl' 'Super Black Clearcoat' 'Seashell Metallic'
#  'NOCTURNE BLACK' 'OSMIUM_GREY_MET' 'Lake Silver Metallic'
#  'White Orchid Pearl' 'Whc' 'Ultra Black Pearl' 'Scuba Blue Metallic'
#  'Smoke' 'Platinum Graphite' 'Ingot Silver Metallic' 'White Gold Metallic'
#  'Selenite Grey Metallic' 'MINERAL BEIGE PEARL' 'Basque Red Pearl II'
#  'SCARLET RED PEARL' 'Starfire Pearl' 'Blue Mirage Metallic'
#  'THUNDER_GREY_ME' 'Silver Streak Mica' 'Mojave Sand' 'Blizzard Pearl'
#  'Mineral Silver' 'Velocity Blu Me' 'Hot Lava' 'CERAMIC WHITE' 'Magma Red'
#  'Alto Blue' 'Pyrite Mica' 'RV Match Walnut Brown Metallic Clearcoat'
#  'SERRANO RED' 'Patriot Blue Pearlcoat' 'Soul Red Crystal'
#  'Diamond White Metallic' 'Omaha Orange' 'blue ray metallic'
#  'Tango Red Pearl' 'Shimmering Silver Pearl' 'Blanco'
#  'Olive Green Pearlcoat' 'Clear White/Black Roof' 'Night Black'
#  'Marlin Blue' 'Iconic Silver Metallic' 'Meteor Gray Mica' 'Galactic Gray'
#  'Pulse Red w/Black Roof' 'Tango Red Metallic'
#  'Light Almond Pearl Metallic' 'Mocha Steel Metallic'
#  'Alpine White Clearcoat' 'PURPLE' 'Titanium Metallic'
#  'White Knuckle Clear Coat' 'Sonic Silver w/Black Roof'
#  'Thunder Gray Metallic' 'Celestial Blue' 'Lunar Blue Metallic'
#  'Casablanca White' 'Azurite Blue Pearl' 'Blue Crush Metallic'
#  'CRYSTAL WHITE' 'designo Cardinal Red Metallic' 'BURSTING_BLUE_M'
#  'Ruby Flare Pearl' 'Twilight Black' 'Slate Metallic' 'Machine Gray'
#  'Black Sand' 'Carbide Gray Metallic' 'Tornado Red' 'Calypso Red'
#  'Not Specified' 'Arctic White' 'Snowflake White Pearl' 'Ultra White'
#  'Cayenne Red' 'Hyper White' 'designo Mocha Black' 'Black Sand Pearl'
#  'Shimmering White Mica' 'Venetian Red' 'MARLIN BLUE' 'Graphite Mica'
#  'Blue Metallic' 'ONYX_BLACK_METALL' 'Java Brown Metallic' 'ONYX_BLACK_M'
#  'Dark Sky Metallic' 'GRAPHITE GRAY' 'Thunder Gray'
#  'Diamond Black Crystal Pearl Coat' 'Remington Red Metallic' 'Tan'
#  'Gloss Black' 'MOLTEN SILVER' 'Champagne Silver Metallic' 'Rapid Red'
#  'Imperial Blue' 'GT Silver Metallic' 'Sakhir Orange Metallic'
#  'Moondust Silver' 'Sparkling Brown Metallic' 'Silver Sky Metallic'
#  'Amber' 'Triathlon Gray Metallic' 'BLACK DIAMOND' 'Teal'
#  'Blackberry Pearl' 'Velocity Blue Metallic' 'BROWN'
#  'Samurai Gray Metallic' 'Labrador Black Pearl' 'Sangria'
#  'Pine Gray Metallic' 'Chalk White' 'Chilipepper Red'
#  'Digital White Metallic' 'Black Diamond' 'Navy Blue Metallic'
#  'Satin White Pearl' 'Premium White Pearl' 'Norad Gray' 'White Gold'
#  'Tuxedo Black' 'San Marino Red' 'Copper' 'Candy White'
#  'Mineral Gray Metallic' 'Ebony' 'Mineral Gray' 'Symphony Silver'
#  'Silver Lightning Metallic' 'Dakar Beige Metallic' 'WH' 'White Cream'
#  'Flame Red Clearcoat' 'Crimson Red Tintcoat'
#  'White Platinum Tri-Coat Metallic' 'RD' 'Gy' 'Glacier White Pearl'
#  'Kodiak Brown Metallic' 'Orange' 'Deep Cherry Red Crystal Pearl'
#  'Luxury White Pearlcoat' 'ICE_WHITE' 'Manhattan Gray Metallic'
#  'Desert Sand Mica' 'Chocolate Metallic' 'Manhattan Noir Metallic'
#  'Jazz Blue Pearlcoat' 'Onyx Black Metallic' 'designo Diamond White'
#  'SEDONA SUNSET' 'ELECTRIC BLUE' 'Milano Red' 'Barolo Black Metallic'
#  'Sunset Bronze Mica' 'Lava Gray Pearl Effect' 'Blue Steel Metallic'
#  'Firmament Blue Metallic' 'Sable Brown Metallic' 'Silverstone Metallic'
#  'Venetian Red Pearl' 'Sparkling Graphite Metallic' 'Eternal Blue Pearl'
#  'Destroyer Gray Clear Coat' 'CHROMIUM SILVER' 'Bianco Fuji (White)'
#  'CHRYSTAL_WHITE' 'Brilliant Silver Metallic' 'burgendy' 'Solar Yellow'
#  'Metallic Slate' 'Ivory Pearl Metallic Tri-Coat' 'Bright Yellow'
#  'Desert Gold Metallic' 'Salsa Red'
#  'Crystal White Pearl Metallic w/Frozen Gray Accent'
#  'blue velvet metallic' 'Blue Jeans Metallic'
#  'Deep Cherry Red Crystal Pearl Coat' 'Billet Silver Metallic Clear C'
#  'Mysterious Blue' 'Blue Print' 'Rosso Scuderia' 'Celestite.'
#  'Indigo Blue' 'Firenze Red Metallic' 'SUMMIT GRAY' 'Quartz Blue Pearl'
#  'Crystal White Pearl Metallic w/BMW i Frozen Blue' 'Moon Shell Mica'
#  'Blue Velvet Metallic' 'PULSE RED' 'Blu By You Pearlcoat'
#  'Dolphin Gray Metallic' 'SPARKLING SILVER' 'Falcon Gray Metallic'
#  'HYPER WHITE' 'Smoke Metallic' 'THUNDER_GREY_M' 'Dark Moss'
#  'ONYX_BLACK_METALLI' 'Starlight Silver Metallic' 'Diamond White Pearl'
#  'Black Stone' 'Northsky Blue Metallic' 'Cayenne Red Metallic'
#  'platinum graphite pearl metallic' 'Green Go Clearcoat'
#  'Sting-Gray Clearcoat' 'Barcelona Red Metallic' 'Metropolitan Gray Mica'
#  'Negro' 'Burnished Copper' 'ONYX_BLACK_METL' 'Infinite Black Metallic'
#  'Shale Gray Metallic' 'Electric Blue' 'Sport Blue Metallic'
#  'Brilliant Blue Metallic' 'GOLD' 'brown' 'Ibiza Blue'
#  'Graystone Metallic' 'Purple' 'CRYSTAL_WHITE_META'
#  'Attitude Black Metallic' 'Shadow' 'Dark Mocha Metallic' 'Aruba Premium'
#  'Quartz Gray Metallic' 'Nolita Gray' 'Havana Metallic' 'Blue Reflex Mica'
#  'Sparkling Ruby' 'Jet Black Metallic' 'Ember Black Metallic' 'Diamond'
#  'designo Selenite Grey Magno' 'Phantom Black Pearl Effect' 'Pewter'
#  'Empire State Gray' 'Denim Blue Metallic' 'Blue Flame' 'Hellraisin'
#  'Granite Metallic Clearcoat' 'Ibis White/Black Roof'
#  'Agate Gray Metallic' 'Storm Blue' 'Cherry Red Tintcoat'
#  'Crystal Red Tintcoat' 'Plum Crazy Pearlcoat' 'Cardinal Red Metallic'
#  'WINTER WHITE' 'Pomegranate Red' 'Santorini Black Metallic'
#  'Ricochet Silver Metallic' 'DILVER'
#  'Bronze Fire Metallic Tinted Clearcoat' 'Green Apple'
#  'Dynamic Sunstone Red' 'Dark Cherry Pearl' 'Dolomite Brown Metallic'
#  'Sepia Bronze Metallic' 'Platinum White Pearl' 'Pacific Blue Pearl'
#  'GRANITE SLATE' 'Laguna Seca Blue' 'Lapis Blue Pearl'
#  'Atlantic Blue Pearl' 'Molten Lava Pearl' 'Shimmering White'
#  'MOJAVE SAND' 'Luxe Silver Metallic' 'Yas Marina Blue Metallic'
#  'Bomber Brown Pearlcoat' 'Floret Silver Metallic' 'Slate'
#  'Titanium Flash Mica' 'Deep Black Pearl' 'Desert Bronze'
#  'Dark Sapphire Blue' 'Moonstone Metallic' 'Toledo Blue Metallic'
#  'Ford Performance Blue Metallic' 'Brilliant Black Pearl' 'Frostbite'
#  'Patriot Blue Pearl' 'PACIFIC BLUE' 'Runway Red' 'Salsa Red Pearl'
#  'Donington Gray Metallic' 'Becketts Black' 'Burgendy']
# franchise_dealer[False  True]
# front_legroom['41.3 in' '42.8 in' '42.6 in' '43.2 in' '40.9 in' '41.4 in' '40.3 in'
#  '41.8 in' '41.1 in' '45.5 in' '44.3 in' nan '44.5 in' '45.3 in' '41.7 in'
#  '39.6 in' '41.2 in' '46.1 in' '41.5 in' '42.2 in' '44.1 in' '40.8 in'
#  '43.6 in' '43 in' '45 in' '41 in' '39.9 in' '42.1 in' '40.6 in' '43.9 in'
#  '40.2 in' '42.5 in' '39.1 in' '42.9 in' '43.1 in' '46.3 in' '42.3 in'
#  '40.5 in' '42 in' '42.4 in' '40.7 in' '--' '43.5 in' '41.6 in' '41.9 in'
#  '40 in' '40.4 in' '44 in' '44.2 in' '45.7 in' '46.9 in' '39 in' '45.4 in'
#  '43.3 in' '43.8 in' '45.1 in' '44.4 in' '45.8 in' '37.7 in' '39.8 in'
#  '39.5 in' '40.1 in' '52.5 in' '43.7 in' '38.8 in' '39.3 in' '35.8 in'
#  '44.7 in' '44.8 in' '39.4 in' '44.6 in' '38.7 in' '67 in' '38.9 in'
#  '46.4 in' '43.4 in']
# fuel_tank_volume['14.8 gal' '15.5 gal' '13.2 gal' '16.2 gal' '15.6 gal' '20.6 gal'
#  '26 gal' '26.4 gal' '15.9 gal' '14.2 gal' '18.5 gal' '16.5 gal' nan
#  '16 gal' '31 gal' '11.9 gal' '18.8 gal' '24.6 gal' '17.4 gal' '16.4 gal'
#  '19.5 gal' '14.9 gal' '24 gal' '20.5 gal' '12.8 gal' '14.5 gal' '18 gal'
#  '15.3 gal' '14 gal' '17.7 gal' '21.5 gal' '19 gal' '13 gal' '9.2 gal'
#  '16.1 gal' '21.1 gal' '13.5 gal' '18.1 gal' '34 gal' '16.6 gal'
#  '12.7 gal' '21 gal' '18.6 gal' '19.2 gal' '22 gal' '20 gal' '16.9 gal'
#  '21.9 gal' '36 gal' '13.6 gal' '19.8 gal' '27.8 gal' '19.4 gal'
#  '17.5 gal' '15.1 gal' '15.8 gal' '14.3 gal' '22.5 gal' '23 gal'
#  '20.1 gal' '23.6 gal' '13.7 gal' '12.4 gal' '17 gal' '22.4 gal'
#  '17.2 gal' '11.8 gal' '38 gal' '20.3 gal' '11 gal' '19.3 gal' '15.7 gal'
#  '23.5 gal' '27.7 gal' '21.7 gal' '32 gal' '12.1 gal' '17.1 gal' '12 gal'
#  '14.7 gal' '23.2 gal' '15.4 gal' '16.3 gal' '9.3 gal' '15 gal' '11.4 gal'
#  '24.1 gal' '17.9 gal' '23.8 gal' '10.6 gal' '28 gal' '23.3 gal'
#  '16.8 gal' '25.4 gal' '17.8 gal' '28.3 gal' '11.3 gal' '--' '27.6 gal'
#  '35 gal' '21.6 gal' '12.2 gal' '23.7 gal' '33.5 gal' '48 gal' '25 gal'
#  '30 gal' '18.4 gal' '11.1 gal' '10.8 gal' '27 gal' '10.5 gal' '24.5 gal'
#  '25.1 gal' '9.5 gal' '22.2 gal' '9 gal']
# fuel_type['Gasoline' 'Hybrid' 'Flex Fuel Vehicle' 'Biodiesel' 'Electric' nan
#  'Diesel']
# height['60.2 in' '65.6 in' '55 in' '64.1 in' '65.4 in' '58.2 in' '77.6 in'
#  '72.8 in' '66.3 in' '63.5 in' '66.2 in' '67.1 in' '58 in' '58.1 in' nan
#  '54.4 in' '74.4 in' '60.7 in' '75.8 in' '69.3 in' '57.4 in' '56.9 in'
#  '66.1 in' '64.8 in' '67.4 in' '57.1 in' '66.5 in' '75.9 in' '66.6 in'
#  '56.5 in' '68.4 in' '57.7 in' '69.4 in' '57.8 in' '57.9 in' '65 in'
#  '64.9 in' '65.9 in' '73.6 in' '59.4 in' '56.7 in' '56.2 in' '54.3 in'
#  '58.7 in' '60.8 in' '81.3 in' '53.5 in' '65.3 in' '64.6 in' '68 in'
#  '69.8 in' '55.7 in' '71 in' '68.6 in' '69.9 in' '66.9 in' '58.9 in'
#  '59.7 in' '76.4 in' '61.6 in' '70.4 in' '66 in' '68.5 in' '70.9 in'
#  '54.5 in' '65.7 in' '68.2 in' '65.1 in' '67.9 in' '76.1 in' '73.9 in'
#  '70.7 in' '71.9 in' '78.8 in' '64.4 in' '79.3 in' '57.5 in' '49 in'
#  '63.4 in' '67.7 in' '56.6 in' '63 in' '74 in' '76.9 in' '56.1 in'
#  '77.5 in' '56.8 in' '68.9 in' '70 in' '57.2 in' '69 in' '76.3 in'
#  '58.4 in' '55.5 in' '67 in' '53.6 in' '71.3 in' '56.3 in' '58.3 in'
#  '77.4 in' '70.2 in' '61 in' '73.7 in' '65.2 in' '57.6 in' '63.6 in'
#  '78.3 in' '60 in' '67.8 in' '63.9 in' '57.3 in' '71.7 in' '70.6 in'
#  '70.8 in' '59.2 in' '63.2 in' '59.6 in' '75.7 in' '79.1 in' '70.1 in'
#  '67.3 in' '64.5 in' '67.6 in' '68.7 in' '77.2 in' '72 in' '78.5 in'
#  '56 in' '55.3 in' '72.1 in' '48.8 in' '54.8 in' '55.1 in' '72.6 in'
#  '69.7 in' '67.2 in' '72.5 in' '69.1 in' '73 in' '67.5 in' '78.4 in'
#  '95.5 in' '57 in' '62.7 in' '53.8 in' '72.7 in' '55.6 in' '75.5 in'
#  '80.2 in' '71.5 in' '60.9 in' '62.2 in' '52 in' '64.2 in' '58.5 in'
#  '81.4 in' '55.9 in' '69.6 in' '59.5 in' '54.2 in' '54.9 in' '107.7 in'
#  '77.7 in' '53.1 in' '53.9 in' '63.8 in' '59.3 in' '55.2 in' '54 in'
#  '71.1 in' '75 in' '68.1 in' '75.6 in' '72.4 in' '51.3 in' '78 in'
#  '52.9 in' '60.6 in' '72.2 in' '55.8 in' '54.6 in' '58.8 in' '77.1 in'
#  '55.4 in' '54.7 in' '68.8 in' '74.9 in' '76 in' '92.8 in' '71.4 in'
#  '69.5 in' '48.5 in' '63.1 in' '59 in' '64.7 in' '53 in' '76.2 in'
#  '76.7 in' '73.8 in' '--' '53.7 in' '63.3 in' '73.1 in' '73.2 in'
#  '74.2 in' '52.8 in' '81.2 in' '83.4 in' '66.8 in' '71.8 in' '66.7 in'
#  '59.8 in' '62.6 in' '74.3 in' '65.5 in' '61.7 in' '62.5 in' '84.8 in'
#  '91.7 in' '74.5 in' '71.2 in' '81.5 in' '66.4 in' '53.3 in' '51.2 in'
#  '54.1 in' '84.6 in' '68.3 in' '59.1 in' '50.9 in' '58.6 in' '47.8 in'
#  '73.4 in' '50.8 in' '82.4 in' '77.9 in' '105.7 in' '61.3 in' '76.6 in'
#  '84.3 in' '77.8 in' '70.3 in' '49.2 in' '83.6 in' '79.8 in' '52.4 in'
#  '72.3 in' '100.7 in' '61.5 in' '62.9 in' '78.1 in' '70.5 in' '60.5 in']
# highway_fuel_economy[ nan  25.  36.  29.  21.  22.  26.  30.  27.  35.  34.  32.  19.  37.
#   23.  20.  38.  24.  28.  31.  43.  40.  33. 121.  17.  46.  39.  53.
#   41.  18.  42.  48.  45.  47. 108.  51.  14.  52.  57.  16.  50.  54.
#   15.  59.  68.  13. 122.]
# horsepower[208. 275. 140. 250. 170. 445. 395. 362. 269. 130. 271. 194. 198. 181.
#   nan 180. 435. 355. 148. 400. 182. 147. 295. 191. 185. 164. 301. 290.
#  184. 245. 173. 300. 187. 179. 175. 138. 176. 240. 260. 304. 115.  78.
#  220. 577. 139. 246. 450. 241. 248. 247. 200. 186. 280. 310. 190. 161.
#  365. 244. 380. 276. 360. 281. 166. 235. 302. 325. 316. 136. 375. 270.
#  207. 120. 354. 291. 600. 335. 420. 282. 425. 210. 283. 494. 237. 385.
#  340. 305. 252. 203. 124. 292. 253. 328. 456. 263. 333. 475. 211. 284.
#  177. 178. 174. 315. 160. 268. 296. 171. 232. 308. 153. 285. 273. 123.
#  141. 330. 390. 265. 485. 204. 201. 169. 266. 311. 320. 158. 108. 415.
#  205. 532. 350. 329. 188. 150. 168. 110. 321. 202. 228. 603. 121. 197.
#  287. 236. 145. 370. 293. 288. 132. 146. 272. 199. 122. 149. 286. 405.
#  503. 196. 404. 323. 345. 230. 556. 192. 127. 137. 424. 398. 152. 117.
#  429. 410. 278. 317. 225. 143. 403. 563. 382. 255. 261. 440. 449. 159.
#  212. 221. 381. 411. 189. 126. 274. 162. 402. 470. 279. 155. 264. 707.
#  128. 469. 454. 144. 797. 306. 455. 303. 523. 142. 550. 259. 156. 242.
#  560. 206. 172. 341. 118. 215. 510. 254. 195. 433. 518. 342. 500. 369.
#  580. 109. 219. 251. 483. 357. 135. 397. 193. 717. 134. 555. 460. 157.
#   99. 348. 367. 277. 372. 436. 505. 165. 552. 617.]
# interior_color['Brown (Tan)' 'Cappuccino' 'Black (Ebony)' 'Gray' 'Medium Ash Gray'
#  'Black' 'None' 'Camel' 'Jet Black' 'Dark Gray' 'jet black'
#  'Brown (Beige)' 'Sand' 'Cashmere' 'Black (Jet Blk Clth)'
#  'CHARCOAL LEATHE' 'Parchment' 'Brown' 'Brown (BEIGE)' 'light gray black'
#  'Jet Black/Medium Titanium' 'Silver (Ebony / Ebony)' 'Crimson red'
#  'Light Frost/Brown' 'Brown (Tan Leather)' 'Cream' 'Red (Sandstone)'
#  'Titan Black' 'Brown (Vintage Tan / Ebony / Ebony Windsor)' 'Graphite'
#  'Black (Light Oyster/Ebony)' 'Ebony Black' 'Slate Black' 'Brown (Wheat)'
#  'Black (charcoal)' 'Diesel Gray/Black' 'BLOND/CHARCOAL' 'gtay' 'Stone'
#  'Black (Macadamia)' 'Red' 'Saddle Brown' 'White (Ash)'
#  'Black (Cappuccino)' 'Medium Earth Gray' 'White' 'Silverstone'
#  'Titan Black w/Clark Plaid' 'White (Ebony Roast)'
#  'Black w/Blue Stitching' 'Neutral Shale' 'CHARCOAL NAPPA' 'Blue'
#  'Brown (Silk Beige/Black)' 'Black (Charcoal)' 'Gray/Black'
#  'Pink (Coral Red/Black)' 'Espresso/Gray' 'White (Cappuccino)' 'Gold'
#  'Off-Black' 'Black (Ebony Roast)' 'Blue (Cashmere)'
#  'Titan Black/Moonrock Gray' 'Dark Slate Gray' 'Brown (TAN)' 'RED - BLACK'
#  'SLATE NAPPA' 'White (Eclipse / Ebony / Ebony)' 'Nougat Brown'
#  'Beyond Blue' 'Jet Black With Jet Black Accents' 'Brown (Stone Beige)'
#  'Satin Black' 'Orange' 'Crimson Red' 'Silver (Light Putty)' 'Red (Fa20)'
#  'Charcoal Black' 'Light Frost Brown' 'Black/Dark Sienna Brown'
#  'Silver (Ash)' 'Jet Black/Jet Black Accents' 'Light Gray'
#  'Brown (Pistachio Beige)' 'Medium Light Stone' 'Saddle'
#  'White (Ebony/Ebony/Ebony)' 'Amaro Brown' 'Brown (Sahara Beige)'
#  'White (Ebony Clth Front Bucket S)' 'Brown (Bisque)' 'Brown (tan)'
#  'Black/Ceramique' 'Ash' 'Blue (DENIM)' 'Smoke Storm'
#  'Silver (CHARCOAL LEATHE)' 'Black/Alloy/Black' 'Brown (Ebony / Ebony)'
#  'Black Interior' 'graphite' 'Black (CHARCOAL LEATHE)' 'Black/Alloy'
#  'White (Ivory)' 'Black/Carbon Black' 'AMBER NAPPA LE' 'GRAY/BLACK'
#  'Black/Graphite' 'Gray (Ebony/Ebony/Ebony)' 'Silver'
#  'White (BLOND LEATHERTT)' 'Black (CHARCOAL LEATH)' 'Black Leather'
#  'Black (Flx3)' 'Sport' 'Gray (Light Platinum With Jet Black Accents)'
#  'BLACK W/ GRAY STITCH' 'Jet Blk Lth' 'Medium Slate' 'Black (Ea10 Ash)'
#  'White (Ivory/Brown)' 'Ruby Red/Black' 'Brown (beige)' 'Black (ebony)'
#  'Kb Bucket Seats Charcoal Black Interior'
#  'Yellow (Cornsilk Beige w/Brown)' 'Jet Black/Ceramic White Accents'
#  'Dark Charcoal' 'Black (Light Putty)' 'Diesel Gray Black' 'Magma Red'
#  'Black Striated' 'Chestnut' 'Crystal Gray' 'Graystone' 'BLOND CITY WEAV'
#  'Red (MAROON BROWN L)' 'White (Carmine)' 'Velvet Beige/Brown'
#  'Blue (Cappuccino)' 'White (Cloud/Ebony)' 'Ivory White/Night Blue'
#  'White (CHARCOAL LEATHE)' 'Brown (Lt Frost Beige/Black)'
#  'Jet Black/Dark Ash' 'Other' 'Dark Gray/Camel' 'Sandstorm/Black'
#  'Blue (Ebony/Ebony/Ebony/Ebony)' 'Blue (Light Oyster/Ebony)'
#  'Red (MAROON BROWN NA)' 'AMBER NAPPA LEA'
#  'Yellow (Cornsilk Beige With Brown Piping)' 'Brown (Macchiato Beige)'
#  'Dark Atmosphere/Medium Ash Gray' 'White (NAPPA LEATHER S)'
#  'White (Cement)' 'carbon black' 'Dark Pebble/Light Pe' 'Red Line'
#  'Espresso Brown' 'Gray (Light Putty)' 'Brown (Silk Beige)'
#  'Brown (Almond Beige)' 'Green (Oyster/Lime Stitch)' 'Sandstone' 'Almond'
#  'Stratus Gray w/Linear' 'designo Black w/Stitching' 'Jet Black / Belmont'
#  'Black/Red' 'Gray (Sandstone)' 'Blue (Sand)' 'Gray (CHARCOAL LEATHE)'
#  'Brown (Corn Silk Beige)' 'Gray/Red' 'Medium Gray' 'camel'
#  'Red (Maroon Brown)' 'designo 2-Tone Sand/' 'White (Parchment)'
#  'Ebony / Lunar' 'Black (Ebony/Ebony/Ebony)' 'Black/Light Graystone'
#  'Light Shale' 'Cement Gray' 'Aero Gray' 'Cinnamon Brown'
#  'Black w/Rock Gray Stitch' 'Rosso/Nero (Red/Black)'
#  'Black (Alpine / Espresso)' 'Gray (CHARCOAL NUBUCK)' 'Brown (Soft Beige)'
#  'slate black' 'White (Cloud)' 'Silver (Sandstone)' 'White (ivory)'
#  'Red (Cappuccino)' 'Red (MAROON BROWN LE)' 'White (Light Putty)' 'Agate'
#  'Black w/Red Stitching' 'Ebony/Saddle Up' 'Black (Sandstone)'
#  'Brown (Harvest Beige)' 'Brown (Sand Beige/Black)' 'Dark Galvanized Gray'
#  'Blue (Light Oyster)' 'Blue (Ebony Clth Front Bucket S)'
#  'White (Dark Auburn)' 'Gray (Ebony/Ebony/Ebony/Ebony)' 'Latte'
#  'Canyon Brown/Light Frost Beige' 'Almond/Mocha' 'Black Alloy'
#  'Ebony/Ebony Accents' 'Dark Ash/Jet Black' 'Mahogany Red' 'Acorn'
#  'Gray (Auburn)' 'Graphite w/Gun Metal' 'Rotor Gray'
#  'light titanium ebony' 'Gray (CHARCOAL LEATH)' 'Blue (Parchment)'
#  'Black/Light Frost Beige' 'Brown (Ginger Beige/Espresso)'
#  'Gray (Cappuccino)' 'White (Cashmere)' 'Black/Iceland Gray'
#  'Black/Ruby Red' 'White (CHARCOAL NUBUCK)' 'CHARCOAL NUBUCK' 'Steel Blue'
#  'BLOND LEATHERET' 'White (Cirrus)' 'Black/Black' 'Cocoa/Dune'
#  'Demonic Red/Black' 'Rioja Red' 'AMBER LEATHER' 'Dk/Lt Slate Gray'
#  'Rock Gray' 'Raven Black' 'White (Pimento/Ebony/Ebony/Pimento/Ebony)'
#  'Nut Brown/Black' 'Red (Jet Blk Clth)' 'Brown (Pearl Beige)'
#  'Ebony/Ebony' 'Black (Ebony Clth Front Bucket S)'
#  'Gray (Medium Light Stone)' 'Brown (Atlas Beige)' 'Moonstone'
#  'Smoke/Black' 'Black (Ebony/Ebony/Ebony/Ebony)' 'Medium Light Camel'
#  'light neutral' 'White (Ivory/Ebony/Ivory/Ebony)' 'Jet Black/Dark Titan'
#  'Ivory White' 'Brown (Fb20)' 'White (CHARCOAL LEAT)' 'Blue (Sandstone)'
#  'White (Sandstone)' 'Mocha' 'Brown (Light Frost Beige Black)'
#  'White (Jet Blk Clth)' 'Black Cloth' 'Chestnut Brown' 'Red (Maroon)'
#  'Anthracite' 'Amber' 'Gray (Ash)' 'Arras Red Design'
#  'Brown (Cardamom Beige)' 'Red (Parchment)' 'AMBER NAPPA L'
#  'Dark Cashmere' 'Silver (Medium Pewter)' 'Silver (Cashmere)'
#  'White (Cognac/Alloy)' 'Titan Black/Palladium Gray'
#  'Red (MAROON BROWM LE)' 'Silver (Cappuccino)' 'Cognac/Black' 'Hickory'
#  'Taupe' 'Gray (Cirrus)' 'White (AMBER NAPPA LEA)'
#  'Brown (Silk Beige/Espresso)' 'White (Acorn/Ebony/Acorn)'
#  'Black Ceramique' 'Ebony/Cirrus' 'Brown (Sand Beige)'
#  'Brown (Tan/Ebony/Tan)' 'Okapi Brown' 'Brown (Venetian Beige)'
#  'Brown (Cappuccino)' 'Brunello' 'Gray (CHARCOAL NAPPA)' 'Medium Graphite'
#  'White (CREAM)' 'Gray (Platinum)' 'Black/Sepia' 'Jet Black/Loft Brown'
#  'Sabbia (Sand Beige)' 'CHARCOAL LEATH' 'Shale/Cocoa Accents'
#  'Blue Bay / Sand' 'Steel' 'Nougat Brown/Black' 'Red/Black'
#  'Black w/Grey Stitching' 'Espresso/Cognac' 'Gold (Sandstone)'
#  'Blue (Medium Light Stone)' 'Giga Amido' 'Dark Earth Gray'
#  'Yellow (Cornsilk Beige)' 'Classic Red/Black' 'Bengal Red/Black'
#  'Giga Ivory White' 'Fiona Red/Black' 'White (Ebony / Terracotta)'
#  'New Saddle Black' 'Dark slate gray' 'Black (Ebony/Cashew)'
#  'Charcoal/Steel' 'Dark Titanium/Light Titanium' 'Black/Blue' 'Steel Gray'
#  'Oyster' 'stone' 'Gray/Dark Gray' 'White (Medium Pewter)' 'almond'
#  'Alloy Black' 'Gone' 'White (Camel)' 'Gray (Parchment)' 'Eclipse/Ebony'
#  'Saddle Brown/Black' 'Macchiato/Magmagrey' 'Charcoal W Seating Surfaces'
#  'Ebony/Ebony/Ebony/Ebony' 'Gray (Ebony / Ebony)' 'Gray (Cloud/Ebony)'
#  'Flaxen w/Shimamoku' 'Slate' 'Blue (Dark Slate)'
#  'White (Jet Blk Lth-Appointed)' 'Silver (Ebony/Ebony/Ebony/Ebony)'
#  'Black in conjunction' 'Brown (Atlas Beige/Black)'
#  'Black Light Frost Beige' 'Canyon Brown/Light F' 'Blue (Ebony/Cashew)'
#  '2-Tone Black/Ceramique' 'White (Warm Ivory)' 'Gray (BLOND/CHARCOAL)'
#  'Silk Beige/Espresso Brown' 'Sakhir Orange/Black' 'Black Sand Monotone'
#  'White (SLATE NAPPA LEA)' 'Cirrus/Ebony/Cirrus/' 'Ebony/Red'
#  'Gallery White' 'Brown (Canberra Beige)' 'Blue (SLATE NAPPA L)'
#  'Db Trim Bucket Seats Charcoal Black Interior' 'Fb20 Black'
#  'Brown (Light Frost Beige/Black)' 'Cognac' 'Red (Greige)'
#  'Gray (Light Platinum)' 'Sepia/Black' 'Brown (Luggage Tan)'
#  'Chromite Gray/Charcoal Black']
# is_new[False  True]
# latitude[40.7774 40.9086 40.8558 40.7333 41.7696 40.7589 40.7827 41.0912 40.6044
#  40.8847 40.6572 40.8775 42.4257 40.6421 41.0473 40.7604 42.1275 41.5668
#  41.4772 42.3361 41.7359 40.7439 42.6507 40.8286 42.4277 40.6229 40.6311
#  18.4439 42.1259 41.2023 42.522  40.8536 42.6054 42.7851 40.8528 41.0265
#  40.6446 40.6685 40.0825 40.8034 18.3988 40.2224 40.8168 42.2388 42.5526
#  40.7457 40.8845 41.3787 40.6241]
# length['174.2 in' '179.2 in' '175.5 in' '180.6 in' '183.1 in' '206.6 in'
#  '232.9 in' '201.6 in' '181.1 in' '163 in' '182 in' '183.5 in' '189.8 in'
#  '190 in' '191.7 in' nan '188.3 in' '224.4 in' '168.3 in' '208.9 in'
#  '187.8 in' '185.1 in' '192.9 in' '185 in' '176.2 in' '185.5 in'
#  '196.2 in' '191.5 in' '191.8 in' '189 in' '191.1 in' '210.7 in'
#  '192.4 in' '179.5 in' '178.3 in' '184.5 in' '192.8 in' '179.1 in'
#  '191.9 in' '167.6 in' '183 in' '188.4 in' '202 in' '175.4 in' '149.4 in'
#  '185.2 in' '176.4 in' '206.5 in' '171.5 in' '181 in' '173 in' '250 in'
#  '194.6 in' '188.9 in' '164.5 in' '183.3 in' '166.6 in' '200 in'
#  '198.3 in' '171.3 in' '188.1 in' '198.5 in' '218.9 in' '204.9 in'
#  '180.2 in' '231.7 in' '195.7 in' '164 in' '188 in' '201.4 in' '201.2 in'
#  '184.4 in' '193.1 in' '203.7 in' '187.4 in' '180.9 in' '161.3 in'
#  '189.6 in' '200.1 in' '184.1 in' '221.9 in' '179.9 in' '193.9 in'
#  '230 in' '204.3 in' '193.8 in' '229 in' '174.8 in' '184.6 in' '180.7 in'
#  '182.8 in' '177.3 in' '194.1 in' '197.9 in' '192.1 in' '166.8 in'
#  '154.1 in' '162.2 in' '203.6 in' '202.9 in' '172.6 in' '165.2 in'
#  '184.7 in' '196.9 in' '202.4 in' '191.3 in' '229.5 in' '209.3 in'
#  '179.3 in' '177.9 in' '195.5 in' '168 in' '202.8 in' '199.3 in'
#  '199.4 in' '210 in' '241.8 in' '170.9 in' '196.8 in' '197.1 in'
#  '191.4 in' '200.6 in' '186.1 in' '182.1 in' '199.9 in' '188.7 in'
#  '187.9 in' '195.4 in' '191.6 in' '199.6 in' '177.4 in' '190.9 in'
#  '181.9 in' '237.9 in' '182.3 in' '189.1 in' '179.4 in' '189.7 in'
#  '193.6 in' '229.8 in' '193.3 in' '172.1 in' '175.2 in' '200.2 in'
#  '243.2 in' '173.9 in' '174.7 in' '190.7 in' '212.7 in' '201 in'
#  '176.7 in' '182.6 in' '183.7 in' '173.4 in' '176.9 in' '204.1 in'
#  '169.5 in' '169.1 in' '194.7 in' '226.4 in' '185.7 in' '198.6 in'
#  '205.3 in' '194.2 in' '207.2 in' '200.8 in' '160 in' '183.6 in'
#  '175.3 in' '180.1 in' '192.5 in' '231.9 in' '173.2 in' '182.7 in'
#  '182.5 in' '196.5 in' '194.4 in' '187.2 in' '224.3 in' '193.2 in'
#  '200.4 in' '196.1 in' '174.3 in' '184.8 in' '203.9 in' '180 in'
#  '184.9 in' '172.8 in' '174.9 in' '186.7 in' '190.2 in' '194.9 in'
#  '178.1 in' '175 in' '166.9 in' '195.1 in' '178.2 in' '189.5 in'
#  '191.2 in' '196.6 in' '239.6 in' '189.2 in' '159 in' '190.6 in'
#  '175.6 in' '183.9 in' '174.5 in' '160.1 in' '203.8 in' '199.1 in'
#  '192.6 in' '195 in' '182.9 in' '197.2 in' '180.3 in' '183.8 in'
#  '188.5 in' '238.8 in' '171.7 in' '192.7 in' '190.3 in' '166.7 in'
#  '172 in' '198.4 in' '254.4 in' '171.9 in' '156.7 in' '180.5 in'
#  '194.5 in' '173.8 in' '263.9 in' '196.4 in' '192.3 in' '177 in'
#  '237.4 in' '260.8 in' '187.3 in' '201.3 in' '197 in' '175.9 in'
#  '186.8 in' '203.3 in' '182.2 in' '204 in' '163.8 in' '162 in' '218 in'
#  '175.8 in' '198.9 in' '161.6 in' '176 in' '205 in' '169.3 in' '168.4 in'
#  '248.4 in' '212.3 in' '207.7 in' '168.5 in' '200.9 in' '190.5 in'
#  '195.8 in' '193.5 in' '186.3 in' '152.8 in' '191 in' '222.4 in' '174 in'
#  '187.5 in' '186.2 in' '189.3 in' '203.2 in' '171.6 in' '201.8 in'
#  '178.7 in' '224.5 in' '162.8 in' '228.9 in' '213.7 in' '202.6 in'
#  '202.5 in' '208.1 in' '192.2 in' '194 in' '186.4 in' '159.6 in'
#  '189.9 in' '188.8 in' '159.1 in' '176.6 in' '184.2 in' '--' '172.4 in'
#  '222.9 in' '243.7 in' '174.4 in' '187.1 in' '185.9 in' '165 in' '215 in'
#  '167.2 in' '232 in' '185.3 in' '197.5 in' '212 in' '248.6 in' '185.6 in'
#  '161.8 in' '194.3 in' '193.7 in' '214.7 in' '221.3 in' '171 in'
#  '172.2 in' '173.5 in' '202.3 in' '193.4 in' '177.6 in' '198.8 in'
#  '202.1 in' '212.4 in' '197.6 in' '222.3 in' '206.9 in' '197.3 in'
#  '207.6 in' '188.2 in' '167.3 in' '200.3 in' '201.9 in' '224 in'
#  '224.1 in' '175.1 in' '161.1 in' '190.4 in' '145.6 in' '206.8 in'
#  '173.6 in' '178.5 in' '211.9 in' '168.7 in' '178.4 in' '266.2 in'
#  '225.8 in' '195.3 in' '205.5 in' '187.6 in' '203 in' '235.8 in'
#  '205.6 in' '190.8 in' '157.4 in' '183.4 in' '181.5 in' '176.5 in'
#  '224.2 in' '207.4 in' '216.7 in' '200.5 in' '139.6 in' '230.6 in'
#  '209 in' '179.8 in' '289.8 in' '169.8 in' '187 in' '244.1 in' '192 in'
#  '207.3 in' '208.3 in' '157.3 in' '229.9 in' '197.4 in' '199.2 in'
#  '174.6 in' '219.9 in' '193 in' '197.7 in' '250.1 in' '198 in' '224.9 in'
#  '235.5 in' '176.8 in' '227.7 in' '202.2 in' '204.7 in' '159.3 in'
#  '239.5 in' '178.9 in' '195.6 in' '196.3 in']
# listed_date['20-08-20' '07-07-20' '26-08-20' '27-08-20' '09-02-20' '12-03-20'
#  '31-07-19' '04-01-20' '01-08-20' '15-08-20' '04-03-20' '26-07-20'
#  '02-09-20' '18-08-20' '24-07-20' '02-08-20' '21-08-20' '13-08-20'
#  '04-09-20' '25-06-20' '05-09-20' '18-12-19' '12-08-20' '24-06-20'
#  '25-08-20' '07-08-20' '25-07-20' '14-06-20' '14-08-20' '03-09-20'
#  '28-08-20' '22-08-20' '15-03-20' '07-09-20' '22-07-20' '01-09-20'
#  '28-06-20' '29-02-20' '29-08-20' '21-07-20' '10-03-20' '06-06-20'
#  '04-08-20' '23-08-20' '02-06-20' '17-07-20' '29-03-19' '06-09-20'
#  '11-08-20' '27-05-20' '05-08-20' '09-09-20' '06-12-19' '28-05-20'
#  '01-07-20' '23-07-20' '06-03-20' '07-03-20' '18-07-20' '15-07-20'
#  '11-08-19' '31-07-20' '08-06-20' '21-06-20' '06-05-20' '19-08-20'
#  '30-07-20' '16-08-20' '30-08-20' '23-02-20' '25-04-20' '01-01-20'
#  '07-02-20' '06-11-19' '10-10-19' '28-02-20' '26-06-20' '14-07-20'
#  '15-12-19' '08-05-20' '12-01-20' '28-07-20' '09-08-20' '14-08-19'
#  '19-06-20' '09-06-20' '04-06-20' '16-07-20' '23-01-20' '08-03-20'
#  '13-03-20' '20-02-20' '22-06-20' '23-03-19' '15-02-20' '09-07-20'
#  '24-08-20' '08-08-20' '09-05-20' '09-11-19' '25-02-20' '03-07-20'
#  '08-09-20' '06-08-20' '29-05-20' '05-06-20' '04-07-20' '29-04-20'
#  '17-05-20' '23-06-20' '18-06-20' '27-06-20' '16-04-20' '18-08-19'
#  '08-12-19' '26-11-19' '20-06-19' '21-02-20' '27-07-19' '06-02-20'
#  '19-07-20' '28-12-19' '12-02-20' '15-01-20' '27-07-20' '04-11-19'
#  '14-05-20' '22-04-20' '10-08-20' '26-07-19' '14-02-20' '09-01-20'
#  '11-07-20' '04-12-19' '01-05-20' '20-05-20' '12-05-20' '12-06-20'
#  '05-01-20' '31-10-19' '21-10-19' '21-05-20' '03-08-20' '24-02-20'
#  '29-12-18' '31-08-20' '21-08-19' '02-07-20' '07-06-20' '28-08-19'
#  '26-01-20' '29-01-20' '20-06-20' '03-04-20' '25-05-19' '29-01-19'
#  '29-07-20' '19-01-20' '10-04-20' '06-09-19' '19-04-20' '20-07-20'
#  '11-06-20' '07-08-19' '22-11-19' '30-01-20' '10-07-20' '30-05-20'
#  '11-04-20' '29-12-19' '22-08-19' '06-01-20' '03-03-20' '19-05-20'
#  '08-07-20' '26-10-19' '23-12-19' '03-06-20' '25-07-19' '05-05-20'
#  '20-01-20' '07-11-19' '16-01-20' '11-01-20' '12-07-20' '18-01-20'
#  '17-08-19' '10-07-19' '08-08-19' '27-03-19' '18-10-19' '08-02-20'
#  '01-12-19' '20-03-20' '14-09-19' '10-02-20' '28-11-19' '26-04-20'
#  '16-12-18' '05-02-20' '30-06-20' '17-01-20' '10-11-19' '27-02-20'
#  '17-02-19' '07-05-20' '26-02-20' '17-10-19' '08-10-19' '19-02-20'
#  '13-12-19' '11-09-19' '11-03-20' '31-12-19' '19-12-19' '17-03-20'
#  '29-06-20' '13-02-20' '06-04-19' '12-12-19' '16-03-20' '26-05-20'
#  '13-07-20' '16-05-20' '26-03-20' '14-03-20' '07-07-19' '19-03-20'
#  '02-10-19' '17-05-19' '23-08-19' '27-03-20' '26-08-19' '23-12-18'
#  '23-03-20' '01-02-20' '13-09-19' '13-04-19' '15-06-20' '10-06-20'
#  '23-10-19' '03-09-19' '23-05-20' '17-06-20' '02-05-20' '23-04-19'
#  '31-01-20' '28-06-19' '30-12-19' '20-10-19' '23-09-19' '20-12-19'
#  '23-04-20' '07-01-20' '15-04-20' '24-12-19' '09-10-19' '05-10-19'
#  '05-06-19' '02-08-19' '25-12-19' '05-12-19' '16-02-20' '03-08-19'
#  '16-08-19' '15-05-20' '19-12-18' '01-06-20' '17-12-19' '22-05-20'
#  '14-12-19' '20-11-19' '03-01-20' '20-07-19' '17-08-20' '06-10-19'
#  '13-06-20' '06-03-19' '04-10-19' '01-03-20' '11-05-20' '02-12-19'
#  '12-10-19' '19-07-19' '14-11-19' '09-04-19' '30-03-19' '19-06-19'
#  '05-03-20' '16-11-19' '15-11-19' '18-03-20' '13-11-19' '27-09-19'
#  '14-01-20' '08-04-20' '01-08-19' '11-10-19' '01-04-20' '08-11-19'
#  '21-12-19' '24-03-20' '31-05-20' '18-02-20' '28-01-20' '21-04-20'
#  '06-04-20' '26-09-19' '20-03-19' '21-03-20' '22-12-19' '16-02-19'
#  '27-12-19' '22-02-20' '29-09-19' '05-05-19' '23-06-19' '27-11-19'
#  '04-02-20' '15-06-19' '10-03-19' '12-09-19' '09-06-19' '21-09-19'
#  '28-10-18' '10-12-19' '12-05-19' '25-01-20' '17-04-20' '24-10-19'
#  '18-04-19' '12-10-18' '02-11-19' '09-04-20' '06-06-19' '30-05-19'
#  '19-09-19' '31-01-19' '31-05-19' '22-07-19' '30-04-20' '22-01-20'
#  '04-07-19' '22-09-19' '23-11-19' '05-07-20' '17-11-19' '07-12-19'
#  '29-06-19' '19-10-19' '19-04-19']
# listing_color['BLACK' 'GRAY' 'RED' 'BLUE' 'SILVER' 'WHITE' 'UNKNOWN' 'YELLOW' 'ORANGE'
#  'GOLD' 'TEAL' 'GREEN' 'BROWN' 'PURPLE']
# longitude[-73.7268 -74.2609 -74.0493 -73.2587 -72.6545 -73.1055 -73.0085 -73.9504
#  -74.4741 -73.8317 -73.6341 -74.0758 -83.2802 -74.2601 -73.5286 -73.5319
#  -72.5108 -72.7734 -72.8124 -83.0289 -72.722  -73.1892 -83.3682 -73.4281
#  -83.3134 -74.4454 -74.2404 -66.0785 -72.5337 -73.8855 -83.6138 -74.0371
#  -83.9244 -83.5479 -74.0677 -73.6323 -74.2532 -73.3953 -74.1737 -73.7358
#  -66.1582 -74.6109 -73.4643 -84.3466 -83.0487 -73.9345 -73.8328 -73.4721
#  -74.0812]
# make_name['INFINITI' 'Lincoln' 'Honda' 'Chevrolet' 'BMW' 'RAM' 'Mercedes-Benz'
#  'Toyota' 'Kia' 'Jeep' 'Hyundai' 'Ford' 'Mitsubishi' 'GMC' 'Mazda'
#  'Volkswagen' 'Acura' 'Dodge' 'Nissan' 'Volvo' 'Cadillac' 'Audi' 'Jaguar'
#  'Land Rover' 'Subaru' 'Genesis' 'Bentley' 'Porsche' 'Chrysler' 'Lexus'
#  'Scion' 'Pontiac' 'Buick' 'Maserati' 'Suzuki' 'FIAT' 'Tesla' 'MINI'
#  'Mercury' 'Saturn' 'Ferrari' 'Fisker']
# maximum_seating['5 seats' '6 seats' '7 seats' nan '4 seats' '8 seats' '2 seats' '3 seats'
#  '15 seats' '9 seats' '--']
# mileage[40186. 53874. 16898. ... 97943. 14313.  8094.]
# model_name['QX30' 'MKC' 'Civic Coupe' 'Corsair' 'Equinox' '7 Series' '1500'
#  'GLS-Class' 'RAV4' 'Soul' 'Cherokee' 'RAV4 Hybrid' 'Sonata' 'Nautilus'
#  'Fusion' 'Outlander Sport' 'Mustang' 'Yukon XL' 'CX-3' 'QX80' 'Jetta'
#  'Grand Cherokee' 'Santa Fe Sport' 'Tucson' 'Terrain' 'MDX' 'MAZDA6'
#  'Sorento' 'Tahoe' 'Journey' 'Forte' 'Elantra' 'Rogue' 'Maxima' 'Optima'
#  'CX-5' 'Altima' 'Trax' 'X3' 'Wrangler Unlimited' 'XC90' 'Outlander' 'XTS'
#  'Civic' 'Mirage' 'A4' 'S-Class' 'Niro' 'Cruze' 'Compass' 'E-PACE'
#  'F-350 Super Duty' '5 Series' 'Range Rover Velar' 'TT' 'Renegade'
#  'Discovery Sport' 'Aviator' 'A3' 'Explorer' 'Forte5' 'Edge' 'XT6'
#  'Town Car' 'Forester' 'G90' 'Golf Alltrack' 'F-150' 'Cadenza' 'Kona'
#  'Suburban' 'Pilot' 'Ioniq Electric' 'Sedona' 'Durango' 'Q60' 'Santa Fe'
#  'Traverse' 'EcoSport' 'Outback' 'QX60' 'Navigator' 'E-Class' 'MKZ'
#  'Silverado 1500' 'Sportage' 'XC60' 'Transit Connect' 'Prius' '3 Series'
#  'Challenger' 'Camry Hybrid' 'Wrangler' 'MX-5 Miata' 'Tiguan' 'Ranger'
#  'Odyssey' 'S60' 'Accent' 'S5' 'Telluride' 'Bentayga'
#  'Mustang Shelby GT350' 'S-TYPE' 'Sierra 1500' 'CR-V' 'M3' 'M5' 'GTI'
#  'Grand Caravan' 'CT5' 'CX-9' 'Cayenne' 'Elantra GT' '300' 'M2' 'Blazer'
#  'Eldorado' 'Camry' 'Sentra' 'Charger' 'Civic Hatchback' 'G37' 'CTS' 'Q7'
#  'C-Class' 'Highlander' 'MAZDA3' 'Pathfinder' 'M-Class' 'Kona Electric'
#  'GLE-Class' 'X6' 'Passat' 'Malibu' 'ES 350' 'Range Rover Evoque' 'Tundra'
#  'Crosstrek' 'Sienna' 'Titan' 'GLA-Class' 'Escape' 'X4' 'Colorado'
#  'Arteon' 'Liberty' 'MKS' 'Mirage G4' 'Jetta Hybrid' 'HR-V' 'M37' 'MKX'
#  'F-250 Super Duty' 'XV Crosstrek' 'El Camino' 'Mark VIII' 'Rio5' 'Q5'
#  'GLC-Class' 'IS 250' 'Accord' 'G80' 'S6' 'CT4' 'Escalade ESV' 'X5'
#  '4 Series' 'Impala Limited' 'RX 350' 'xA' 'Gladiator' 'G8' 'R8'
#  'Escalade' 'S4' 'Veloster N' 'Focus RS' 'S90' 'Fusion Hybrid' 'Stinger'
#  'A6' 'Trailblazer' 'Acadia' 'Veloster' 'MDX Hybrid Sport' 'Discovery'
#  'XT5' 'Range Rover Sport' 'Sprinter' 'Q50' 'Venue' 'Verano' 'RC 350'
#  'Accord Coupe' 'Malibu Maxx' 'Fiesta' 'Pacifica' 'CLS-Class' 'Avenger'
#  'ILX' '4Runner' 'Prius v' 'Cobalt' 'Murano' '2500' 'WRX STI' 'Focus'
#  'Taurus' 'Corolla' 'TLX' 'CX-30' '86' 'Seltos' 'XC40' 'ATS'
#  'Optima Hybrid' 'G70' 'Vibe' 'Cube' 'Cruze Limited' 'K5' 'Impreza' 'XT4'
#  'Rio' 'SQ5' 'Transit Passenger' 'M4' '200' 'Volt' 'Continental' 'Camaro'
#  '3500' 'Town & Country' 'GLK-Class' 'X4 M' 'Impala' 'Legacy' 'Ghibli'
#  'Levante' '2 Series' 'RDX' 'CTS-V' 'A5' 'X7' 'S3' 'Sonata Hybrid'
#  '5 Series Gran Turismo' 'Quattroporte' 'A-Class' 'Fit' 'Golf' 'Encore'
#  'GL-Class' 'Tacoma' 'Ioniq Hybrid' 'WRX' 'SL-Class' 'Armada'
#  '6 Series Gran Turismo' 'Passport' 'RL' 'A5 Sportback' 'F-PACE' 'S80'
#  'G-Class' 'Eclipse Cross' '3 Series Gran Turismo' 'RX 330' 'Flex'
#  'Xterra' 'CLA-Class' 'Ioniq Hybrid Plug-In ' 'SX4' 'ProMaster' 'Routan'
#  'Accord Hybrid' 'TL' 'Yukon' 'Atlas' '124 Spider' 'XC70'
#  'Sonata Hybrid Plug-In ' 'Expedition' 'V60' '6 Series' 'Altima Hybrid'
#  'GX' 'Bolt EV' 'HHR' 'Lancer' 'Rogue Sport' 'Metris' 'Jetta SportWagen'
#  'ProMaster City' 'C70' 'TTS' 'Dakota' 'Niro Hybrid Plug-In' 'E-Series'
#  'TSX' 'Avalon' 'X3 M' 'QX70' 'C-HR' 'Golf R' 'IS 350' 'Cayenne E-Hybrid'
#  'Palisade' 'Sonic' 'RSX' 'Model S' 'Zephyr' 'Prius Prime'
#  'Range Rover Hybrid' 'Regal' 'Panamera' 'Canyon' 'Defender'
#  'Elantra Touring' 'Sebring' 'Q3' 'NX 200t' 'CR-Z' 'GS 350' 'RS 7' 'DTS'
#  'Mustang Shelby GT500' 'Veloster Turbo' 'X-TYPE' 'MKT' 'Patriot'
#  'Enclave' 'Savana Cargo' '1 Series' 'Beetle' 'Outlander Hybrid Plug-in '
#  'S-Class Coupe' 'Cooper' 'Ridgeline' 'C-Max Hybrid' 'Range Rover'
#  'Grand Marquis' 'GranTurismo' 'V90' 'SLK-Class' 'Avalon Hybrid'
#  'Frontier' 'R-Class' 'QX50' 'Express Cargo' 'ION' 'i8' 'A7'
#  'S5 Sportback' 'G35' 'F430' 'Corolla Hybrid' 'X1' 'ES 300' '500'
#  'Sierra 2500HD' 'RAM 1500' 'Sprinter Cargo' 'Countryman' 'Avalanche'
#  'Cooper Clubman' 'CC' 'X6 M' 'A8' 'A4 Avant' 'Milan' 'Prius c' 'SRX'
#  'Genesis Coupe' 'Grand Prix' 'LS 460' 'AMG GT' 'Corvette' 'Transit Cargo'
#  'New Yorker' 'CTS Coupe' 'Highlander Hybrid' 'Q8' 'Karma' '5500 Chassis'
#  'C/K 1500' 'RAM 2500' 'A4 Allroad' 'Sierra 3500HD' 'CT6' 'Element'
#  'Nitro' 'Versa Note' 'S40' 'S7' 'QX60 Hybrid' 'STS']
# power['208 hp @ 5,500 RPM' '275 hp @ 5,500 RPM' '140 hp @ 6,300 RPM'
#  '250 hp @ 5,500 RPM' '170 hp @ 5,600 RPM' '445 hp @ 5,500 RPM'
#  '395 hp @ 5,600 RPM' '362 hp @ 5,000 RPM' '269 hp @ 6,200 RPM'
#  '130 hp @ 6,300 RPM' '270 hp @ 5,250 RPM' nan '198 hp @ 6,300 RPM'
#  '335 hp @ 5,500 RPM' '181 hp @ 6,000 RPM' '271 hp @ 6,500 RPM'
#  '435 hp @ 6,500 RPM' '355 hp @ 5,600 RPM' '148 hp @ 6,000 RPM'
#  '400 hp @ 5,800 RPM' '182 hp @ 6,700 RPM' '147 hp @ 5,000 RPM'
#  '295 hp @ 6,400 RPM' '191 hp @ 6,100 RPM' '185 hp @ 6,000 RPM'
#  '164 hp @ 6,200 RPM' '301 hp @ 6,500 RPM' '290 hp @ 6,200 RPM'
#  '184 hp @ 5,700 RPM' '173 hp @ 6,000 RPM' '148 hp @ 6,500 RPM'
#  '170 hp @ 6,000 RPM' '300 hp @ 6,400 RPM' '245 hp @ 6,000 RPM'
#  '290 hp @ 6,400 RPM' '187 hp @ 6,000 RPM' '182 hp @ 6,000 RPM'
#  '179 hp @ 6,000 RPM' '175 hp @ 5,500 RPM' '138 hp @ 4,900 RPM'
#  '176 hp @ 6,000 RPM' '240 hp @ 5,000 RPM' '260 hp @ 3,600 RPM'
#  '304 hp @ 6,800 RPM' '115 hp @ 6,100 RPM' '78 hp @ 6,000 RPM'
#  '220 hp @ 4,450 RPM' '577 hp @ 5,500 RPM' '138 hp @ 6,300 RPM'
#  '180 hp @ 6,400 RPM' '246 hp @ 5,500 RPM' '450 hp @ 2,800 RPM'
#  '360 hp @ 5,150 RPM' '248 hp @ 5,200 RPM' '247 hp @ 5,500 RPM'
#  '200 hp @ 5,100 RPM' '290 hp @ 6,500 RPM' '173 hp @ 6,500 RPM'
#  '310 hp @ 6,700 RPM' '190 hp @ 4,200 RPM' '161 hp @ 6,200 RPM'
# ...
#  '266 lb-ft @ 3,400 RPM' '174 lb-ft @ 4,100 RPM' '149 lb-ft @ 4,450 RPM'
#  '174 lb-ft @ 4,000 RPM' '270 lb-ft @ 4,800 RPM' '295 lb-ft @ 3,200 RPM'
#  '183 lb-ft @ 4,000 RPM' '510 lb-ft @ 3,000 RPM' '132 lb-ft @ 4,500 RPM'
#  '273 lb-ft @ 3,500 RPM' '270 lb-ft @ 3,000 RPM' '266 lb-ft @ 2,800 RPM'
#  '273 lb-ft @ 1,300 RPM' '407 lb-ft @ 3,950 RPM' '258 lb-ft @ 1,600 RPM'
#  '295 lb-ft @ 2,200 RPM' '128 lb-ft @ 4,750 RPM' '258 lb-ft @ 1,450 RPM'
#  '410 lb-ft @ 4,300 RPM' '280 lb-ft @ 3,000 RPM' '221 lb-ft @ 1,600 RPM'
#  '238 lb-ft @ 3,000 RPM' '250 lb-ft @ 4,800 RPM' '113 lb-ft @ 4,500 RPM'
#  '369 lb-ft @ 1,370 RPM' '262 lb-ft @ 5,200 RPM' '664 lb-ft @ 1,350 RPM'
#  '221 lb-ft @ 4,500 RPM' '375 lb-ft @ 3,000 RPM' '161 lb-ft @ 4,400 RPM'
#  '406 lb-ft @ 1,850 RPM' '165 lb-ft @ 4,000 RPM' '161 lb-ft @ 4,200 RPM'
#  '472 lb-ft @ 2,200 RPM' '553 lb-ft @ 1,800 RPM' '260 lb-ft @ 4,400 RPM'
#  '630 lb-ft @ 3,000 RPM' '405 lb-ft @ 2,400 RPM' '320 lb-ft @ 2,500 RPM'
#  '369 lb-ft @ 3,500 RPM' '390 lb-ft @ 4,000 RPM' '343 lb-ft @ 1,400 RPM'
#  '269 lb-ft @ 5,000 RPM' '300 lb-ft @ 4,000 RPM' '273 lb-ft @ 1,600 RPM'
#  '125 lb-ft @ 3,600 RPM' '250 lb-ft @ 3,500 RPM' '162 lb-ft @ 1,700 RPM'
#  '269 lb-ft @ 5,200 RPM' '480 lb-ft @ 1,800 RPM' '253 lb-ft @ 3,100 RPM'
#  '325 lb-ft @ 2,900 RPM' '136 lb-ft @ 4,600 RPM' '253 lb-ft @ 4,800 RPM'
#  '248 lb-ft @ 4,700 RPM' '470 lb-ft @ 4,300 RPM' '259 lb-ft @ 4,800 RPM'
#  '480 lb-ft @ 2,000 RPM' '210 lb-ft @ 1,750 RPM' '170 lb-ft @ 4,100 RPM'
#  '181 lb-ft @ 3,900 RPM' '300 lb-ft @ 1,200 RPM' '206 lb-ft @ 1,700 RPM'
#  '185 lb-ft @ 4,000 RPM' '375 lb-ft @ 4,300 RPM' '260 lb-ft @ 1,450 RPM'
#  '184 lb-ft @ 2,500 RPM' '263 lb-ft @ 4,700 RPM' '401 lb-ft @ 4,000 RPM'
#  '258 lb-ft @ 1,250 RPM' '171 lb-ft @ 4,500 RPM' '295 lb-ft @ 2,100 RPM'
#  '186 lb-ft @ 4,250 RPM' '275 lb-ft @ 4,000 RPM' '383 lb-ft @ 5,000 RPM'
#  '254 lb-ft @ 3,000 RPM' '369 lb-ft @ 2,000 RPM' '258 lb-ft @ 1,950 RPM'
#  '235 lb-ft @ 4,000 RPM' '270 lb-ft @ 4,250 RPM' '125 lb-ft @ 3,500 RPM'
#  '127 lb-ft @ 4,300 RPM' '270 lb-ft @ 5,200 RPM' '380 lb-ft @ 2,750 RPM'
#  '407 lb-ft @ 4,000 RPM' '365 lb-ft @ 3,750 RPM' '250 lb-ft @ 4,500 RPM'
#  '330 lb-ft @ 1,600 RPM' '290 lb-ft @ 4,500 RPM' '475 lb-ft @ 4,100 RPM'
#  '119 lb-ft @ 4,850 RPM' '267 lb-ft @ 4,500 RPM' '185 lb-ft @ 4,800 RPM'
#  '250 lb-ft @ 4,000 RPM' '470 lb-ft @ 3,500 RPM' '260 lb-ft @ 2,000 RPM'
#  '245 lb-ft @ 4,700 RPM' '255 lb-ft @ 5,000 RPM' '293 lb-ft @ 5,000 RPM'
#  '148 lb-ft @ 1,850 RPM' '350 lb-ft @ 1,800 RPM' '253 lb-ft @ 3,500 RPM'
#  '460 lb-ft @ 4,100 RPM' '330 lb-ft @ 1,380 RPM' '262 lb-ft @ 5,300 RPM'
#  '138 lb-ft @ 4,200 RPM' '105 lb-ft @ 4,200 RPM' '310 lb-ft @ 2,000 RPM'
#  '415 lb-ft @ 4,600 RPM' '240 lb-ft @ 4,000 RPM' '398 lb-ft @ 6,500 RPM'
#  '162 lb-ft @ 4,200 RPM' '300 lb-ft @ 1,400 RPM' '302 lb-ft @ 3,500 RPM'
#  '280 lb-ft @ 4,250 RPM' '179 lb-ft @ 2,000 RPM' '350 lb-ft @ 3,200 RPM'
#  '354 lb-ft @ 1,600 RPM' '193 lb-ft @ 4,850 RPM' '172 lb-ft @ 4,000 RPM'
#  '184 lb-ft @ 5,000 RPM' '254 lb-ft @ 5,000 RPM' '275 lb-ft @ 3,600 RPM'
#  '184 lb-ft @ 1,600 RPM' '170 lb-ft @ 4,500 RPM' '270 lb-ft @ 1,750 RPM'
#  '237 lb-ft @ 4,000 RPM' '221 lb-ft @ 2,700 RPM' '200 lb-ft @ 1,750 RPM'
#  '627 lb-ft @ 2,500 RPM' '325 lb-ft @ 1,400 RPM' '161 lb-ft @ 4,000 RPM'
#  '220 lb-ft @ 3,200 RPM' '300 lb-ft @ 1,300 RPM' '184 lb-ft @ 1,500 RPM'
#  '350 lb-ft @ 1,600 RPM' '223 lb-ft @ 4,300 RPM' '171 lb-ft @ 4,900 RPM'
#  '590 lb-ft @ 2,000 RPM' '280 lb-ft @ 4,800 RPM' '207 lb-ft @ 3,950 RPM'
#  '202 lb-ft @ 4,200 RPM' '262 lb-ft @ 4,000 RPM' '369 lb-ft @ 1,800 RPM'
#  '180 lb-ft @ 3,600 RPM' '267 lb-ft @ 5,200 RPM' '460 lb-ft @ 1,500 RPM'
#  '240 lb-ft @ 4,400 RPM' '266 lb-ft @ 4,000 RPM' '150 lb-ft @ 4,000 RPM'
#  '248 lb-ft @ 4,400 RPM' '262 lb-ft @ 4,700 RPM' '161 lb-ft @ 4,500 RPM'
#  '850 lb-ft @ 1,700 RPM' '181 lb-ft @ 4,250 RPM' '290 lb-ft @ 4,000 RPM'
#  '270 lb-ft @ 2,500 RPM' '278 lb-ft @ 4,400 RPM' '251 lb-ft @ 3,500 RPM'
#  '160 lb-ft @ 4,000 RPM' '128 lb-ft @ 4,400 RPM' '130 lb-ft @ 4,700 RPM'
#  '350 lb-ft @ 1,500 RPM' '156 lb-ft @ 6,400 RPM' '258 lb-ft @ 1,800 RPM'
#  '264 lb-ft @ 4,800 RPM' '178 lb-ft @ 3,600 RPM' '470 lb-ft @ 2,500 RPM'
#  '270 lb-ft @ 5,000 RPM' '235 lb-ft @ 4,500 RPM' '260 lb-ft @ 1,400 RPM'
#  '118 lb-ft @ 4,400 RPM' '260 lb-ft @ 1,700 RPM' '258 lb-ft @ 4,400 RPM'
#  '127 lb-ft @ 4,800 RPM' '350 lb-ft @ 3,500 RPM' '332 lb-ft @ 1,380 RPM'
#  '450 lb-ft @ 1,800 RPM' '169 lb-ft @ 3,750 RPM' '112 lb-ft @ 4,500 RPM'
#  '350 lb-ft @ 3,000 RPM' '400 lb-ft @ 2,500 RPM' '185 lb-ft @ 3,250 RPM'
#  '262 lb-ft @ 4,250 RPM' '280 lb-ft @ 4,000 RPM' '660 lb-ft @ 1,400 RPM'
#  '284 lb-ft @ 5,300 RPM' '295 lb-ft @ 1,500 RPM' '180 lb-ft @ 3,900 RPM'
#  '406 lb-ft @ 2,350 RPM' '442 lb-ft @ 2,600 RPM' '186 lb-ft @ 4,400 RPM'
#  '406 lb-ft @ 1,750 RPM' '278 lb-ft @ 4,800 RPM' '268 lb-ft @ 4,800 RPM'
#  '369 lb-ft @ 4,500 RPM' '369 lb-ft @ 1,520 RPM' '242 lb-ft @ 4,400 RPM'
#  '280 lb-ft @ 1,600 RPM' '551 lb-ft @ 3,800 RPM' '335 lb-ft @ 4,000 RPM'
#  '479 lb-ft @ 1,500 RPM' '125 lb-ft @ 4,000 RPM' '280 lb-ft @ 1,900 RPM'
#  '264 lb-ft @ 5,300 RPM' '132 lb-ft @ 4,600 RPM' '123 lb-ft @ 4,850 RPM'
#  '428 lb-ft @ 4,500 RPM' '472 lb-ft @ 1,500 RPM' '145 lb-ft @ 4,000 RPM'
#  '339 lb-ft @ 4,250 RPM' '221 lb-ft @ 1,250 RPM' '106 lb-ft @ 4,800 RPM'
#  '175 lb-ft @ 3,500 RPM' '516 lb-ft @ 3,500 RPM' '406 lb-ft @ 1,500 RPM'
#  '252 lb-ft @ 5,300 RPM' '271 lb-ft @ 5,000 RPM' '265 lb-ft @ 4,600 RPM'
#  '258 lb-ft @ 2,000 RPM' '345 lb-ft @ 3,900 RPM' '385 lb-ft @ 3,400 RPM'
#  '136 lb-ft @ 4,250 RPM' '561 lb-ft @ 1,750 RPM' '152 lb-ft @ 4,200 RPM'
#  '400 lb-ft @ 2,750 RPM' '207 lb-ft @ 1,700 RPM' '310 lb-ft @ 2,500 RPM'
#  '191 lb-ft @ 4,400 RPM' '410 lb-ft @ 3,500 RPM' '332 lb-ft @ 4,500 RPM'
#  '221 lb-ft @ 3,200 RPM' '129 lb-ft @ 4,300 RPM' '417 lb-ft @ 4,300 RPM'
#  '561 lb-ft @ 2,000 RPM' '384 lb-ft @ 1,800 RPM' '400 lb-ft @ 3,850 RPM'
#  '254 lb-ft @ 4,000 RPM' '242 lb-ft @ 3,600 RPM' '177 lb-ft @ 4,250 RPM'
#  '339 lb-ft @ 2,700 RPM' '200 lb-ft @ 4,000 RPM' '391 lb-ft @ 2,800 RPM'
#  '148 lb-ft @ 5,000 RPM' '413 lb-ft @ 1,500 RPM' '369 lb-ft @ 1,600 RPM'
#  '252 lb-ft @ 4,900 RPM' '281 lb-ft @ 4,000 RPM' '136 lb-ft @ 3,500 RPM'
#  '220 lb-ft @ 4,000 RPM' '327 lb-ft @ 3,400 RPM' '375 lb-ft @ 3,500 RPM'
#  '338 lb-ft @ 4,400 RPM' '251 lb-ft @ 5,000 RPM' '516 lb-ft @ 1,800 RPM'
#  '324 lb-ft @ 3,600 RPM' '266 lb-ft @ 1,800 RPM' '230 lb-ft @ 4,000 RPM'
#  '180 lb-ft @ 3,800 RPM' '161 lb-ft @ 4,300 RPM' '225 lb-ft @ 2,750 RPM'
#  '215 lb-ft @ 4,000 RPM' '170 lb-ft @ 4,000 RPM' '205 lb-ft @ 4,800 RPM'
#  '163 lb-ft @ 4,400 RPM' '207 lb-ft @ 2,200 RPM' '145 lb-ft @ 4,200 RPM'
#  '401 lb-ft @ 3,600 RPM' '255 lb-ft @ 5,200 RPM' '167 lb-ft @ 4,400 RPM'
#  '434 lb-ft @ 4,500 RPM' '182 lb-ft @ 3,900 RPM' '329 lb-ft @ 3,500 RPM'
#  '295 lb-ft @ 1,450 RPM' '122 lb-ft @ 4,200 RPM' '330 lb-ft @ 1,400 RPM'
#  '590 lb-ft @ 3,500 RPM' '154 lb-ft @ 4,500 RPM' '406 lb-ft @ 2,000 RPM'
#  '269 lb-ft @ 4,500 RPM' '162 lb-ft @ 4,000 RPM' '443 lb-ft @ 1,800 RPM'
#  '465 lb-ft @ 4,200 RPM' '147 lb-ft @ 4,400 RPM' '174 lb-ft @ 3,800 RPM'
#  '205 lb-ft @ 4,000 RPM' '210 lb-ft @ 1,800 RPM' '223 lb-ft @ 5,700 RPM'
#  '171 lb-ft @ 4,800 RPM' '400 lb-ft @ 4,500 RPM' '275 lb-ft @ 5,000 RPM'
#  '269 lb-ft @ 3,000 RPM' '650 lb-ft @ 4,000 RPM' '350 lb-ft @ 2,500 RPM'
#  '860 lb-ft @ 1,600 RPM' '172 lb-ft @ 4,300 RPM' '270 lb-ft @ 3,400 RPM'
#  '220 lb-ft @ 4,400 RPM' '113 lb-ft @ 4,600 RPM' '479 lb-ft @ 1,750 RPM'
#  '236 lb-ft @ 1,750 RPM' '442 lb-ft @ 4,000 RPM' '267 lb-ft @ 267 RPM'
#  '139 lb-ft @ 3,900 RPM' '280 lb-ft @ 1,800 RPM' '273 lb-ft @ 1,800 RPM'
#  '707 lb-ft @ 4,500 RPM' '277 lb-ft @ 4,800 RPM' '516 lb-ft @ 1,000 RPM'
#  '262 lb-ft @ 5,000 RPM' '612 lb-ft @ 1,900 RPM' '200 lb-ft @ 2,500 RPM'
#  '141 lb-ft @ 4,000 RPM' '174 lb-ft @ 1,600 RPM' '250 lb-ft @ 1,750 RPM'
#  '232 lb-ft @ 3,000 RPM' '394 lb-ft @ 4,200 RPM' '502 lb-ft @ 2,500 RPM'
#  '295 lb-ft @ 2,500 RPM' '150 lb-ft @ 4,500 RPM' '168 lb-ft @ 4,000 RPM'
#  '567 lb-ft @ 1,960 RPM' '146 lb-ft @ 4,450 RPM' '240 lb-ft @ 5,000 RPM'
#  '295 lb-ft @ 1,300 RPM' '315 lb-ft @ 4,000 RPM' '460 lb-ft @ 2,500 RPM'
#  '226 lb-ft @ 4,500 RPM' '147 lb-ft @ 4,800 RPM' '354 lb-ft @ 1,400 RPM'
#  '232 lb-ft @ 4,000 RPM' '258 lb-ft @ 4,000 RPM' '274 lb-ft @ 3,600 RPM'
#  '516 lb-ft @ 1,750 RPM' '182 lb-ft @ 4,500 RPM' '125 lb-ft @ 4,200 RPM'
#  '192 lb-ft @ 1,500 RPM' '222 lb-ft @ 5,100 RPM' '295 lb-ft @ 4,400 RPM'
#  '510 lb-ft @ 4,500 RPM' '195 lb-ft @ 1,750 RPM' '178 lb-ft @ 3,000 RPM'
#  '165 lb-ft @ 4,400 RPM' '243 lb-ft @ 3,250 RPM' '258 lb-ft @ 2,400 RPM'
#  '295 lb-ft @ 2,250 RPM' '253 lb-ft @ 4,000 RPM' '373 lb-ft @ 4,200 RPM'
#  '200 lb-ft @ 2,750 RPM' '249 lb-ft @ 4,500 RPM' '122 lb-ft @ 2,600 RPM'
#  '384 lb-ft @ 2,000 RPM' '170 lb-ft @ 3,750 RPM' '209 lb-ft @ 4,400 RPM'
#  '114 lb-ft @ 4,250 RPM' '245 lb-ft @ 4,500 RPM' '185 lb-ft @ 2,750 RPM'
#  '461 lb-ft @ 2,500 RPM' '265 lb-ft @ 4,000 RPM' '236 lb-ft @ 2,800 RPM'
#  '443 lb-ft @ 1,750 RPM' '133 lb-ft @ 4,500 RPM' '230 lb-ft @ 3,000 RPM'
#  '260 lb-ft @ 2,800 RPM' '214 lb-ft @ 3,500 RPM' '162 lb-ft @ 3,600 RPM'
#  '650 lb-ft @ 4,800 RPM' '361 lb-ft @ 4,750 RPM' '291 lb-ft @ 4,000 RPM'
#  '260 lb-ft @ 4,500 RPM' '373 lb-ft @ 4,400 RPM' '455 lb-ft @ 4,400 RPM'
#  '145 lb-ft @ 4,400 RPM' '516 lb-ft @ 4,500 RPM' '556 lb-ft @ 3,800 RPM'
#  '162 lb-ft @ 4,400 RPM' '105 lb-ft @ 4,800 RPM' '259 lb-ft @ 4,100 RPM'
#  '266 lb-ft @ 2,750 RPM' '343 lb-ft @ 5,250 RPM' '370 lb-ft @ 4,200 RPM'
#  '156 lb-ft @ 1,400 RPM' '379 lb-ft @ 3,600 RPM' '254 lb-ft @ 4,700 RPM'
#  '210 lb-ft @ 4,000 RPM' '150 lb-ft @ 2,500 RPM' '765 lb-ft @ 1,600 RPM'
#  '200 lb-ft @ 1,250 RPM' '114 lb-ft @ 4,800 RPM' '207 lb-ft @ 1,350 RPM'
#  '262 lb-ft @ 4,900 RPM' '656 lb-ft @ 4,800 RPM' '149 lb-ft @ 4,200 RPM'
#  '268 lb-ft @ 5,200 RPM' '144 lb-ft @ 4,300 RPM' '162 lb-ft @ 1,250 RPM'
#  '242 lb-ft @ 4,500 RPM' '169 lb-ft @ 4,400 RPM' '500 lb-ft @ 1,500 RPM'
#  '420 lb-ft @ 4,600 RPM' '336 lb-ft @ 2,800 RPM' '395 lb-ft @ 4,200 RPM'
#  '360 lb-ft @ 3,400 RPM' '172 lb-ft @ 4,500 RPM' '325 lb-ft @ 2,100 RPM'
#  '223 lb-ft @ 5,100 RPM' '295 lb-ft @ 5,100 RPM' '139 lb-ft @ 6,100 RPM'
#  '347 lb-ft @ 4,100 RPM' '258 lb-ft @ 1,850 RPM' '384 lb-ft @ 5,000 RPM'
#  '400 lb-ft @ 4,400 RPM' '148 lb-ft @ 4,100 RPM' '365 lb-ft @ 2,000 RPM'
#  '380 lb-ft @ 3,500 RPM' '171 lb-ft @ 2,800 RPM' '265 lb-ft @ 2,400 RPM'
#  '273 lb-ft @ 5,200 RPM' '401 lb-ft @ 4,400 RPM' '384 lb-ft @ 3,500 RPM'
#  '475 lb-ft @ 4,200 RPM' '222 lb-ft @ 4,400 RPM' '236 lb-ft @ 3,200 RPM'
#  '470 lb-ft @ 4,800 RPM' '186 lb-ft @ 5,000 RPM' '245 lb-ft @ 4,900 RPM'
#  '236 lb-ft @ 1,500 RPM' '181 lb-ft @ 2,700 RPM' '254 lb-ft @ 3,700 RPM'
#  '600 lb-ft @ 1,600 RPM' '106 lb-ft @ 4,500 RPM' '444 lb-ft @ 1,500 RPM'
#  '250 lb-ft @ 3,800 RPM' '265 lb-ft @ 4,200 RPM' '107 lb-ft @ 4,400 RPM'
#  '246 lb-ft @ 4,400 RPM' '406 lb-ft @ 1,400 RPM' '502 lb-ft @ 1,500 RPM'
#  '252 lb-ft @ 3,200 RPM']
# transmission['A' 'CVT' nan 'M' 'Dual Clutch']
# transmission_display['7-Speed Automatic' '6-Speed Automatic' '5-Speed Automatic'
#  '8-Speed Automatic' '6-Speed Automatic Overdrive' 'Automatic'
#  '9-Speed Automatic' 'Continuously Variable Transmission' nan
#  '4-Speed Automatic' '6-Speed Manual' '6-Speed Dual Clutch' 'Manual'
#  '9-Speed Automatic Overdrive' '8-Speed Automatic Overdrive'
#  '5-Speed Manual' '5-Speed Automatic Overdrive'
#  '4-Speed Automatic Overdrive' '7-Speed CVT' '1-Speed Automatic'
#  '7-Speed Dual Clutch' '2-Speed Automatic' '6-Speed Manual Overdrive'
#  '3-Speed Automatic']
# wheel_system['AWD' 'FWD' '4WD' nan 'RWD' '4X2']
# wheelbase['106.3 in' '105.9 in' '104.3 in' '106.7 in' '107.3 in' '126.4 in'
#  '144.6 in' '121.1 in' '104.7 in' '101.2 in' '106.6 in' '110 in'
#  '112.2 in' nan '107.1 in' '130 in' '112.5 in' '105.7 in' '114.7 in'
#  '111.8 in' '105.1 in' '111 in' '111.4 in' '109.4 in' '110.4 in'
#  '120.9 in' '113.8 in' '106.5 in' '109.3 in' '114.8 in' '106.2 in'
#  '100.6 in' '110.6 in' '118.4 in' '111.7 in' '103.1 in' '96.5 in'
#  '124.6 in' '103.8 in' '105.6 in' '159.8 in' '117.1 in' '113.1 in'
#  '97.2 in' '107.9 in' '119 in' '112.8 in' '112.7 in' '117.4 in' '103 in'
#  '124.4 in' '103.5 in' '144.4 in' '112.4 in' '102.4 in' '120.5 in'
#  '119.8 in' '110.2 in' '118.9 in' '103.9 in' '99.2 in' '108.1 in'
#  '114.2 in' '131.6 in' '113.2 in' '143.5 in' '115.7 in' '140.5 in'
#  '108.9 in' '114.6 in' '116.2 in' '111.2 in' '96.8 in' '90.9 in'
#  '100.4 in' '109.8 in' '125.9 in' '118.1 in' '101.6 in' '117.9 in'
#  '114.5 in' '122.4 in' '110.7 in' '98 in' '103.6 in' '121.2 in' '119.1 in'
#  '116 in' '115.3 in' '122.5 in' '153.5 in' '120 in' '106 in' '112.6 in'
#  '108 in' '120.2 in' '113.4 in' '109.2 in' '149.5 in' '115.5 in'
#  '103.7 in' '119.3 in' '151.6 in' '128.3 in' '106.1 in' '112.9 in'
#  '104.4 in' '102.8 in' '137 in' '113 in' '107.5 in' '145 in' '120.6 in'
#  '112.1 in' '118.5 in' '110.5 in' '93.3 in' '116.9 in' '104.5 in'
#  '109.5 in' '114.4 in' '115.1 in' '115 in' '106.9 in' '147.5 in'
#  '144.3 in' '107.4 in' '108.7 in' '112.3 in' '121.6 in' '117.5 in'
#  '104.8 in' '147.4 in' '103.3 in' '149 in' '146 in' '106.4 in' '164.2 in'
#  '111.6 in' '99.6 in' '104.1 in' '147.6 in' '169 in' '108.8 in' '108.5 in'
#  '108.3 in' '118 in' '118.3 in' '122.2 in' '94.9 in' '137.3 in' '104.9 in'
#  '98.4 in' '160 in' '127.4 in' '99 in' '123.2 in' '102.9 in' '107.7 in'
#  '111.9 in' '107.8 in' '95.4 in' '102.5 in' '101.5 in' '113.3 in' '133 in'
#  '145.7 in' '136 in' '117.3 in' '110.8 in' '95.6 in' '112 in' '99.4 in'
#  '144.5 in' '--' '104.2 in' '156.8 in' '126 in' '98.6 in' '131.1 in'
#  '140.2 in' '138 in' '158 in' '113.6 in' '114 in' '132.5 in' '140.9 in'
#  '121.9 in' '116.1 in' '113.7 in' '131 in' '115.6 in' '118.2 in'
#  '135.2 in' '98.7 in' '115.9 in' '97.1 in' '122 in' '176 in' '138.8 in'
#  '120.4 in' '115.8 in' '95.7 in' '126.6 in' '150.5 in' '135 in' '103.2 in'
#  '107 in' '98.8 in' '128.5 in' '101.7 in' '119.2 in' '139.8 in' '90.6 in'
#  '144.2 in' '170.3 in' '155.2 in' '122.9 in' '140.6 in' '114.9 in'
#  '129.9 in' '158.9 in' '123.4 in' '117.8 in' '104 in' '110.9 in'
#  '122.8 in' '153.7 in' '101.4 in' '116.7 in' '116.4 in']
# width['82 in' '84.1 in' '68.9 in' '83 in' '72.6 in' '85.4 in' '82.1 in'
#  '84.3 in' '71.5 in' '70.9 in' '73.2 in' '72.2 in' '86.1 in' '83.5 in' nan
#  '81.9 in' '80.5 in' '69.6 in' '79.9 in' '72.5 in' '70.8 in' '84.8 in'
#  '74 in' '72.8 in' '77.7 in' '72.4 in' '74.4 in' '73.4 in' '81 in'
#  '83.7 in' '70.1 in' '69.9 in' '83.3 in' '72 in' '82.6 in' '73.8 in'
#  '72.9 in' '67.5 in' '65.6 in' '80.3 in' '83.9 in' '71.1 in' '70.7 in'
#  '80 in' '82.2 in' '105.9 in' '84.4 in' '76.8 in' '79.6 in' '85.6 in'
#  '89.9 in' '77.2 in' '90.2 in' '85.8 in' '77.3 in' '76.9 in' '79 in'
#  '75.4 in' '97 in' '73.6 in' '77.5 in' '89.3 in' '85.5 in' '80.8 in'
#  '74.2 in' '78.5 in' '81.3 in' '93.8 in' '81.5 in' '78.6 in' '79.4 in'
#  '73 in' '83.2 in' '69 in' '68.3 in' '70.3 in' '91.5 in' '68.1 in'
#  '78.3 in' '87.5 in' '96.8 in' '71.6 in' '80.2 in' '88.5 in' '75.9 in'
#  '74.1 in' '78.1 in' '76.7 in' '75.5 in' '69.3 in' '75 in' '77 in'
#  '69.8 in' '87.1 in' '79.5 in' '75.2 in' '71.7 in' '82.7 in' '78.9 in'
#  '80.7 in' '81.1 in' '77.1 in' '70.5 in' '73.7 in' '82.8 in' '72.3 in'
#  '65.7 in' '70 in' '78.2 in' '75.8 in' '84 in' '74.8 in' '67.9 in'
#  '82.5 in' '86 in' '74.6 in' '66.7 in' '71.3 in' '80.1 in' '80.9 in'
#  '84.2 in' '83.1 in' '72.7 in' '74.7 in' '81.8 in' '87.4 in' '68 in'
#  '81.2 in' '96 in' '71.8 in' '69.7 in' '71.4 in' '66.9 in' '67.8 in'
#  '90.4 in' '70.6 in' '85.7 in' '72.1 in' '86.5 in' '97.4 in' '79.3 in'
#  '70.4 in' '82.3 in' '79.1 in' '96.5 in' '85 in' '71.9 in' '87.3 in'
#  '76 in' '78.4 in' '68.5 in' '83.8 in' '79.2 in' '79.8 in' '71.2 in'
#  '73.3 in' '80.6 in' '92.3 in' '88.8 in' '69.1 in' '97.6 in' '84.9 in'
#  '73.9 in' '73.1 in' '93.4 in' '81.4 in' '77.4 in' '--' '76.2 in'
#  '66.8 in' '82.9 in' '88.3 in' '74.9 in' '84.6 in' '104.9 in' '67 in'
#  '86.4 in' '77.8 in' '66.5 in' '85.2 in' '91.8 in' '69.5 in' '69.2 in'
#  '86.7 in' '75.6 in' '70.2 in' '71 in' '67.2 in' '76.3 in' '66.2 in'
#  '75.7 in' '78.8 in' '95.7 in' '73.5 in' '95.5 in' '83.4 in' '76.1 in'
#  '98.1 in' '86.2 in' '69.4 in']
# year[2017 2010 2020 2018 2007 2011 2019 2016 2021 2013 2014 2012 2004 2015
#  2009 1993 2006 2000 2008 2002 1978 1998 2005 1996 1999 1995 2001 2003
#  1989 1997]
# price[21495 22459 24799 ... 25945 37950 31055]

# %%
Back leg room, front leg room, fuel tank volumn, height, length, listed date, wheel base, width

# %%
correlation_matrix = car.corr()

import seaborn as sns
import matplotlib.pyplot as plt

# Create a heatmap to visualize correlations
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# `(Task 2, Question 1 Text Here - insert more cells as required)`

# %% [markdown]
# **Task 2, Question 2** Create at least 5 new features from the existing numerical variables which contain multiple items of information, for example you could extract maximum torque and torque rpm from the torque variable.
# (2 marks)

# %%
## Task 2, Question 2 Code Here

Torque, power

# %% [markdown]
# `(Task 2, Question 2 Text Here - insert more cells as required)`

# %% [markdown]
# **Task 2, Question 3**: Impute missing values for all features in both the training and test datasets.
# (3 marks)

# %%
## Task 2, Question 3 Code Here

car.fillna({'horsepower': car['horsepower'].mean(), 
           'mileage': car['mileage'].mean()
          }, inplace=True)

# %% [markdown]
# `(Task 2, Question 3 Text Here - insert more cells as required)`

# %% [markdown]
# **Task 2, Question 4**: Encode all categorical variables appropriately as discussed in class.
#
# - Where multiple values are given for an observation encode the observation as 'other'.
# - Where a categorical feature contains more than 5 unique values, map the features into 5 most frequent values + 'other' and then encode appropriately. For instance, map colours into 5 basic colours + 'other': [red, yellow, green, blue, purple, other] and then encode.
# (2 marks)

# %%
## Task 2, Question 4 Code Here

paypred = pd.get_dummies(data = paypred, columns = ['Claim_Segment_Name',
       'Claim_How_Reported_Name', 'RTW_Plan_Status_Name',
       'Policy_Issue_State_Name', 'Accident_type_code', 'Nature_of_loss_code',
       'Bodily_location_code', 'Med_Cert_Capacity',
       'Interstate_workers_flag'])

# %% [markdown]
# `(Task 2, Question 4 Text Here - insert more cells as required)`

# %% [markdown]
# **Task 2, Question 5**: Perform any other actions you think need to be done on the data before constructing predictive models, and clearly explain what you have done.
# (1 marks)

# %%
## Task 2, Question 5 Code Here

# %% [markdown]
# `(Task 2, Question 5 Text Here - insert more cells as required)`

# %% [markdown]
# **Task 2, Question 6**: Perform exploratory data analysis to measure the relationship between the features and the target and carefully write up your findings.
# (2 marks)

# %%
## Task 2, Question 6 Code Here
Map, date - for any imbalance

# %%
import seaborn as sns

sns.pairplot(car)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\lib\site-packages\numpy\lib\histograms.py:351, in _unsigned_subtract(a, b)
#     350 try:
# --> 351     dt = signed_to_unsigned[dt.type]
#     352 except KeyError:
#
# KeyError: <class 'numpy.bool_'>
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 3>()
#       1 import seaborn as sns
# ----> 3 sns.pairplot(car)
#       5 plt.show()
#
# File ~\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~\lib\site-packages\seaborn\axisgrid.py:2126, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2124 diag_kws.setdefault("legend", False)
#    2125 if diag_kind == "hist":
# -> 2126     grid.map_diag(histplot, **diag_kws)
#    2127 elif diag_kind == "kde":
#    2128     diag_kws.setdefault("fill", True)
#
# File ~\lib\site-packages\seaborn\axisgrid.py:1478, in PairGrid.map_diag(self, func, **kwargs)
#    1476     plot_kwargs.setdefault("hue_order", self._hue_order)
#    1477     plot_kwargs.setdefault("palette", self._orig_palette)
# -> 1478     func(x=vector, **plot_kwargs)
#    1479     ax.legend_ = None
#    1481 self._add_axis_labels()
#
# File ~\lib\site-packages\seaborn\distributions.py:1462, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1451 estimate_kws = dict(
#    1452     stat=stat,
#    1453     bins=bins,
#    (...)
#    1457     cumulative=cumulative,
#    1458 )
#    1460 if p.univariate:
# -> 1462     p.plot_univariate_histogram(
#    1463         multiple=multiple,
#    1464         element=element,
#    1465         fill=fill,
#    1466         shrink=shrink,
#    1467         common_norm=common_norm,
#    1468         common_bins=common_bins,
#    1469         kde=kde,
#    1470         kde_kws=kde_kws,
#    1471         color=color,
#    1472         legend=legend,
#    1473         estimate_kws=estimate_kws,
#    1474         line_kws=line_kws,
#    1475         **kwargs,
#    1476     )
#    1478 else:
#    1480     p.plot_bivariate_histogram(
#    1481         common_bins=common_bins,
#    1482         common_norm=common_norm,
#    (...)
#    1492         **kwargs,
#    1493     )
#
# File ~\lib\site-packages\seaborn\distributions.py:441, in _DistributionPlotter.plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     438     weights = None
#     440 # Do the histogram computation
# --> 441 heights, edges = estimator(observations, weights=weights)
#     443 # Rescale the smoothed curve to match the histogram
#     444 if kde and key in densities:
#
# File ~\lib\site-packages\seaborn\_statistics.py:386, in Histogram.__call__(self, x1, x2, weights)
#     384 """Count the occurrences in each bin, maybe normalize."""
#     385 if x2 is None:
# --> 386     return self._eval_univariate(x1, weights)
#     387 else:
#     388     return self._eval_bivariate(x1, x2, weights)
#
# File ~\lib\site-packages\seaborn\_statistics.py:361, in Histogram._eval_univariate(self, x, weights)
#     359 bin_kws = self.bin_kws
#     360 if bin_kws is None:
# --> 361     bin_kws = self.define_bin_params(x, weights=weights, cache=False)
#     363 density = self.stat == "density"
#     364 hist, bin_edges = np.histogram(
#     365     x, **bin_kws, weights=weights, density=density,
#     366 )
#
# File ~\lib\site-packages\seaborn\_statistics.py:269, in Histogram.define_bin_params(self, x1, x2, weights, cache)
#     266 """Given data, return numpy.histogram parameters to define bins."""
#     267 if x2 is None:
# --> 269     bin_edges = self._define_bin_edges(
#     270         x1, weights, self.bins, self.binwidth, self.binrange, self.discrete,
#     271     )
#     273     if isinstance(self.bins, (str, Number)):
#     274         n_bins = len(bin_edges) - 1
#
# File ~\lib\site-packages\seaborn\_statistics.py:260, in Histogram._define_bin_edges(self, x, weights, bins, binwidth, binrange, discrete)
#     258     bin_edges = np.arange(start, stop + step, step)
#     259 else:
# --> 260     bin_edges = np.histogram_bin_edges(
#     261         x, bins, binrange, weights,
#     262     )
#     263 return bin_edges
#
# File <__array_function__ internals>:180, in histogram_bin_edges(*args, **kwargs)
#
# File ~\lib\site-packages\numpy\lib\histograms.py:669, in histogram_bin_edges(a, bins, range, weights)
#     472 r"""
#     473 Function to calculate only the edges of the bins used by the `histogram`
#     474 function.
#    (...)
#     666
#     667 """
#     668 a, weights = _ravel_and_check_weights(a, weights)
# --> 669 bin_edges, _ = _get_bin_edges(a, bins, range, weights)
#     670 return bin_edges
#
# File ~\lib\site-packages\numpy\lib\histograms.py:409, in _get_bin_edges(a, bins, range, weights)
#     406     n_equal_bins = 1
#     407 else:
#     408     # Do not call selectors on empty arrays
# --> 409     width = _hist_bin_selectors[bin_name](a, (first_edge, last_edge))
#     410     if width:
#     411         n_equal_bins = int(np.ceil(_unsigned_subtract(last_edge, first_edge) / width))
#
# File ~\lib\site-packages\numpy\lib\histograms.py:264, in _hist_bin_auto(x, range)
#     230 """
#     231 Histogram bin estimator that uses the minimum width of the
#     232 Freedman-Diaconis and Sturges estimators if the FD bin width is non-zero.
#    (...)
#     261 _hist_bin_fd, _hist_bin_sturges
#     262 """
#     263 fd_bw = _hist_bin_fd(x, range)
# --> 264 sturges_bw = _hist_bin_sturges(x, range)
#     265 del range  # unused
#     266 if fd_bw:
#
# File ~\lib\site-packages\numpy\lib\histograms.py:73, in _hist_bin_sturges(***failed resolving arguments***)
#      54 """
#      55 Sturges histogram bin estimator.
#      56
#    (...)
#      70 h : An estimate of the optimal bin width for the given data.
#      71 """
#      72 del range  # unused
# ---> 73 return _ptp(x) / (np.log2(x.size) + 1.0)
#
# File ~\lib\site-packages\numpy\lib\histograms.py:29, in _ptp(x)
#      22 def _ptp(x):
#      23     """Peak-to-peak value of x.
#      24
#      25     This implementation avoids the problem of signed integer arrays having a
#      26     peak-to-peak value that cannot be represented with the array's data type.
#      27     This function returns an unsigned value for signed integer arrays.
#      28     """
# ---> 29     return _unsigned_subtract(x.max(), x.min())
#
# File ~\lib\site-packages\numpy\lib\histograms.py:353, in _unsigned_subtract(a, b)
#     351     dt = signed_to_unsigned[dt.type]
#     352 except KeyError:
# --> 353     return np.subtract(a, b, dtype=dt)
#     354 else:
#     355     # we know the inputs are integers, and we are deliberately casting
#     356     # signed to unsigned
#     357     return np.subtract(a, b, casting='unsafe', dtype=dt)
#
# TypeError: numpy boolean subtract, the `-` operator, is not supported, use the bitwise_xor, the `^` operator, or the logical_xor function instead.

# %%
import matplotlib.pyplot as plt

corrmat = car.corr()
# print(corrmat.round(3).to_string())
# corrmat

f, ax = plt.subplots(figsize=(20, 10))
sns.heatmap(corrmat, annot=True, vmax=.8, square=True)
plt.show()

# %% [markdown]
# `(Task 2, Question 6 Text Here - insert more cells as required)`

# %% [markdown]
# ---
# ## Task 3: Fit and tune a forecasting model/Submit predictions/Report score and ranking
#
# Make sure you **clearly explain each step** you do both in text and on the recoded video.
# This task must not create any additional features and has to use on the dataset constructed in Task 2.
#
# 1. Build at least 3 machine learning (ML) regression models taking into account the outcomes of Tasks 1 & 2 (Explain Carefully)
# 2. Fit the models and tune hyperparameters via cross-validation: make sure you comment and explain each step clearly
# 3. Select your best algorithm, create predictions using the test dataset, and submit your predictions on Kaggle's competition page
# 4. Provide Kaggle ranking and **score** (screenshot your best submission) and comment
# 5. Make sure your Python code works, so that a marker that can replicate your all Kaggle Score
#
# - Hint: to perform well you will need to iterate Tasks 2 and Task 3.
#
# Total Marks: 12

# %%
#Task 3 code here

import numpy as np
from sklearn.model_selection import train_test_split

# %%
#X1 = car.drop(columns = ['price', 'vin'])
X = car[['horsepower', 'mileage', 'year']].values

y = car['price'].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
sc.fit(X_train)

X_train = sc.transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt

# Train a Random Forest Regressor
regressor = RandomForestRegressor(n_estimators=100, random_state=42)
regressor.fit(X_train, y_train)

# Get feature importances from the trained model
feature_importances = regressor.feature_importances_

# Create a DataFrame to display feature names and their importance scores
feature_names = X1.columns
importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importances})

# Sort the DataFrame by importance scores in descending order
importance_df = importance_df.sort_values(by='Importance', ascending=False)

# Create a bar plot to visualize feature importances
plt.figure(figsize=(10, 6))
plt.barh(importance_df['Feature'], importance_df['Importance'])
plt.xlabel('Feature Importance')
plt.ylabel('Feature')
plt.title('Feature Importance in Random Forest Regressor')
plt.gca().invert_yaxis()  # Invert the y-axis to show the most important features at the top
plt.show()

# Display the sorted feature importances
print(importance_df)
# Out:
#       Feature  Importance
# 0  horsepower    0.472205
# 2        year    0.300847
# 1     mileage    0.226948

# %%
from sklearn.model_selection import GridSearchCV, KFold
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb
from sklearn.linear_model import Ridge
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.kernel_ridge import KernelRidge
from sklearn.svm import SVR
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.neural_network import MLPRegressor

models = {
    #'Linear Regression': LinearRegression(),
    'Random Forest': RandomForestRegressor(),
    'XGBoost': xgb.XGBRegressor(),
    #'Ridge Regression': Ridge(),
    'Gradient Boosted Regression Trees': GradientBoostingRegressor(),
    #'Kernel Ridge Regressor' : KernelRidge(),
    #'Support Vector Regressor' : SVR(),
    'Bagging Regressor' : BaggingRegressor(),
    'Adaptive Boost Regressor' : AdaBoostRegressor(),
    'Multi-layer Perceptron Regressor' : MLPRegressor()
}

# Define the parameters for grid search
params = {
    #'Linear Regression': { },
    'Random Forest': { 'n_estimators': [50, 100, 200], 'max_depth': [None, 10, 20, 30], 'min_samples_split': [2, 5, 10], 'min_samples_leaf': [2, 5, 10] },
    'XGBoost': { 'n_estimators': [50, 100, 200], 'learning_rate': [0.01, 0.05, 0.1], 'max_depth': [3, 5, 7, 9], 'alpha': [0.1, 0.5, 1.0, 5.0, 10.0] },
    #'Ridge Regression': { 'alpha': [0.1, 0.5, 1.0, 5.0, 10.0] },
    'Gradient Boosted Regression Trees': { 'n_estimators': [50, 100, 200], 'learning_rate': [0.01, 0.05, 0.1], 'max_depth': [3, 5, 7, 9], 'min_samples_split': [2, 5, 10], 'min_samples_leaf': [2, 5, 10]  },
    #'Kernel Ridge Regressor': {'alpha': [0.1, 1.0, 10.0],'kernel': ['linear', 'polynomial', 'rbf'], 'gamma': [0.1, 1.0, 10.0]},
    #'Support Vector Regressor': {'kernel': ['linear', 'rbf', 'poly'], 'C': [0.1, 1.0, 10.0], 'gamma': [0.1, 1.0, 10.0]},
    'Bagging Regressor': {'n_estimators': [10, 50, 100], 'max_samples': [0.5, 1.0]},
    'Adaptive Boost Regressor': {'n_estimators': [50, 100, 200], 'learning_rate': [0.01, 0.1, 1.0]},
    'Multi-layer Perceptron Regressor': {'hidden_layer_sizes': [(50,), (100, 50), (100, 100, 50)], 'activation': ['relu', 'tanh']},
}

# Initialize an empty dictionary to store the best models
best_models = {}

# Perform grid search
for model_name in models:
    model = models[model_name]
    param_grid = params[model_name]
    grid_search = GridSearchCV(model, param_grid, scoring='neg_mean_squared_error', cv=KFold(n_splits=5, shuffle=True, random_state=42))
    grid_search.fit(X_train, y_train)
    
    best_models[model_name] = grid_search.best_estimator_
    
    print(f"Best parameters for {model_name}: {grid_search.best_params_}")
    print(f"Best {model_name} cross-validation score (MSE): {np.abs(grid_search.best_score_)}")
    print("\n")
# Out:
# Best parameters for Random Forest: {'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200}
# Best Random Forest cross-validation score (MSE): 41648494.86313461
#
#
# Best parameters for XGBoost: {'alpha': 5.0, 'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 200}
# Best XGBoost cross-validation score (MSE): 41556355.597835496
#
#
# Best parameters for Gradient Boosted Regression Trees: {'learning_rate': 0.05, 'max_depth': 7, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200}
# Best Gradient Boosted Regression Trees cross-validation score (MSE): 43008500.68491782
#
#
# Best parameters for Bagging Regressor: {'max_samples': 0.5, 'n_estimators': 100}
# Best Bagging Regressor cross-validation score (MSE): 41108258.99727075
#
#
# Best parameters for Adaptive Boost Regressor: {'learning_rate': 0.01, 'n_estimators': 200}
# Best Adaptive Boost Regressor cross-validation score (MSE): 75351646.07993768
# C:\Users\TChu0702\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\TChu0702\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\TChu0702\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\TChu0702\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\TChu0702\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\TChu0702\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\TChu0702\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\TChu0702\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\TChu0702\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\TChu0702\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\TChu0702\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\TChu0702\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\TChu0702\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\TChu0702\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\TChu0702\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\TChu0702\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\TChu0702\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\TChu0702\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\TChu0702\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\TChu0702\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\TChu0702\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\TChu0702\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\TChu0702\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\TChu0702\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\TChu0702\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\TChu0702\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\TChu0702\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\TChu0702\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\TChu0702\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\TChu0702\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Best parameters for Multi-layer Perceptron Regressor: {'activation': 'relu', 'hidden_layer_sizes': (100, 100, 50)}
# Best Multi-layer Perceptron Regressor cross-validation score (MSE): 64760567.00462158
# C:\Users\TChu0702\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
# Evaluate the best models on the test set
for model_name, model in best_models.items():
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    print(f"{model_name} Test MSE: {mse}")
# Out:
# Random Forest Test MSE: 70403684.4764724
# XGBoost Test MSE: 73960433.70615731
# Gradient Boosted Regression Trees Test MSE: 75801875.28605482
# Bagging Regressor Test MSE: 74854682.43816747
# Adaptive Boost Regressor Test MSE: 98358502.52062277
# Multi-layer Perceptron Regressor Test MSE: 100785935.8054003

# %%
from sklearn.ensemble import StackingRegressor
from sklearn.tree import DecisionTreeRegressor

estimators = [('Random Forest',  RandomForestRegressor()), ('Bagging Regressor', BaggingRegressor())]
            
stacking_reg = StackingRegressor(estimators=estimators, final_estimator = DecisionTreeRegressor(random_state = 1))

stacking_reg.fit(X_train, y_train)


y_train_pred_stacking = stacking_reg.predict(X_train)
y_test_pred_stacking = stacking_reg.predict(X_test)


print(f'MSE train: {mean_squared_error(y_train, y_train_pred_stacking):.3f}, test: {mean_squared_error(y_test, y_test_pred_stacking):.3f}')
# Out:
# MSE train: 57980655.635, test: 110694788.136

# %%
from sklearn.feature_selection import RFE

rfe = RFE(RandomForestRegressor())
rfe.fit(X_train, y_train)

selected_features = rfe.support_

X_train_rfe = X_train[:, selected_features]
X_test_rfe = X_test[:, selected_features]

lr.fit(X_train_rfe, y_train)
lr_pred = lr.predict(X_test_rfe)

lr_mse = mean_squared_error(y_test, lr_pred)

print(lr_mse)
# Out:
# 216455669.58935234

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components = 20)

X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)

lr.fit(X_train_pca, y_train)

lr_pred = lr.predict(X_test_pca)

lr_mse = mean_squared_error(y_test, lr_pred)

print(lr_mse)

from sklearn.decomposition import KernelPCA

kpca = KernelPCA(n_components=2, kernel='rbf', gamma=15)
X_kpca = kpca.fit_transform(X_train)

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
lda = LDA(n_components = 2)
X_train_lda = lda.fit_transform(X_train_scaled, y_train)

pd.DataFrame(X_train_lda)

# %%
test = pd.read_csv('test.csv')

# %%
test.isna().sum()
# Out:
# vin                       0
# back_legroom             53
# body_type                 2
# city                      0
# city_fuel_economy       237
# daysonmarket              0
# dealer_zip                0
# engine_displacement      59
# engine_type              36
# exterior_color            0
# franchise_dealer          0
# front_legroom            53
# fuel_tank_volume         53
# fuel_type                29
# height                   53
# highway_fuel_economy    237
# horsepower               59
# interior_color            0
# is_new                    0
# latitude                  0
# length                   53
# listed_date               0
# listing_color             0
# longitude                 0
# make_name                 0
# maximum_seating          53
# mileage                  76
# model_name                0
# power                   126
# savings_amount            0
# seller_rating             3
# torque                  141
# transmission             13
# transmission_display     13
# wheel_system             43
# wheelbase                53
# width                    53
# year                      0
# dtype: int64

# %%
test.fillna({'horsepower': test['horsepower'].mean(), 
           'mileage': test['mileage'].mean()
          }, inplace=True)

# %%
from sklearn.pipeline import make_pipeline

pipe_lr = make_pipeline(StandardScaler(),
                        #PCA(n_components=2),
                        RandomForestRegressor(n_estimators=50, max_depth=None, min_samples_split=2, min_samples_leaf = 2, random_state=42))

pipe_lr.fit(X, y)

print(f'Train MSE: {pipe_lr.score(X, y):.3f}')
# Out:
# Train MSE: 0.932

# %%
test[['horsepower', 'mileage', 'year']].values
# Out:
# array([[1.7000e+02, 3.0396e+04, 2.0170e+03],
#        [3.5500e+02, 5.7901e+04, 2.0170e+03],
#        [1.4700e+02, 3.5488e+04, 2.0180e+03],
#        ...,
#        [2.6800e+02, 6.9990e+04, 2.0120e+03],
#        [1.9100e+02, 1.0000e+01, 2.0200e+03],
#        [2.8100e+02, 4.3429e+04, 2.0160e+03]])

# %%
X_test = test[['horsepower', 'mileage', 'year']].values

y_pred = pipe_lr.predict(X_test)

# %%
test['price'] = y_pred

test[['vin', 'price']].to_csv('submission.csv', index=False)

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(estimator=pipe_lr, X=X, y=y, cv=10, n_jobs=1)

print(scores)

# %%
import pickle
pickle.dump(forest, open("forest.pkl", "wb"))

saved_forest = pickle.load(open("forest.pkl", 'rb'))

y_train_pred_saved = saved_forest.predict(X_train)
y_test_pred_saved = saved_forest.predict(X_test)

print(f'MSE train: {mean_squared_error(y_train, y_train_pred_saved):.3f}, test: {mean_squared_error(y_test, y_test_pred_saved):.3f}')

# %% [markdown]
# `(Task 3 - insert more cells as required)`

# %% [markdown]
# ## Marking Criteria
#
# - Marking Rubrics
#     - Problem Description - 12 marks
#     - Data Cleaning - 12 marks
#     - Building Forecasting models - 12 marks
#     - Competition Points - 4 marks
#
#
# - To receive full marks your solutions must satisfy the following criteria:
#     - Provide Python solutions that follow the modelling methodology developed in BUSA8001
#     - Written answers explain your logic and Python code in detail, and beformulated in easy to understand full sentences
#
# ---
# ---
